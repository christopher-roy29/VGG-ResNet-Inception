# %%
import numpy as np
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Conv2D, AveragePooling2D, Dropout, Activation, Flatten
from keras.layers import BatchNormalization, add, Input
from keras import optimizers
from keras import regularizers
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Model
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score,accuracy_score,recall_score,confusion_matrix

# %% [markdown]
# ## Data Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train = x_train.astype('float32') /255
x_test = x_test.astype('float32') /255
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)
# Mean normalization
mean = np.mean(x_train, axis=0)
x_train -= mean
x_test -= mean

# %%
print(x_train.shape[-3:],y_train.shape)
# Out:
# (32, 32, 3) (50000, 100)

# %% [markdown]
# ## Building the Model

# %%
def residual_layer(input,filters,strides,kernel=3):
  model = Conv2D(filters,kernel_size=kernel,strides=strides,padding='same',kernel_regularizer=regularizers.l2(0.001))
  model = model(input)
  model = BatchNormalization()(model)
  return model

# %%
# check for batch_normalization layer added back to back in residual layer
def create_model():
    inp = Input(shape=x_train.shape[-3:])
    m1_res = residual_layer(input=inp,filters=32,strides=1)
    m1_res = Activation('relu')(m1_res)
    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=2)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = residual_layer(input=m1_res,filters=64,strides=2,kernel=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=2)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = residual_layer(input=m1_res,filters=128,strides=2,kernel=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m1_res = AveragePooling2D(pool_size=8)(m1_res)
    m2 = Flatten()(m1_res)
    m2 = Dense(100,activation='softmax')(m2)
    model = Model(inputs=inp,outputs=m2)
    return model

# %%
model = create_model()
model.summary()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 32)   896         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 32)   128         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 32, 32, 32)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 32)   9248        activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 32)   128         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 32, 32, 32)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 32)   9248        activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 32)   128         conv2d_65[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 32, 32, 32)   0           activation_57[0][0]
#                                                                  batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 32, 32, 32)   0           add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 32)   9248        activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 32)   128         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 32, 32, 32)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 32, 32)   9248        activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 32, 32, 32)   128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 32, 32, 32)   0           activation_59[0][0]
#                                                                  batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 32, 32)   0           add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 32)   9248        activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 32)   128         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 32, 32, 32)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 32)   9248        activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 32, 32)   128         conv2d_69[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 32, 32, 32)   0           activation_61[0][0]
#                                                                  batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 32)   0           add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 16, 16, 64)   18496       activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 16, 64)   256         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 16, 16, 64)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 16, 16, 64)   2112        activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 16, 16, 64)   36928       activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 16, 16, 64)   256         conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 16, 16, 64)   256         conv2d_71[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 16, 16, 64)   0           batch_normalization_72[0][0]
#                                                                  batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 16, 16, 64)   0           add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 16, 16, 64)   36928       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 16, 16, 64)   256         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 16, 16, 64)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 16, 16, 64)   36928       activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 16, 16, 64)   256         conv2d_74[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 16, 16, 64)   0           activation_65[0][0]
#                                                                  batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 16, 16, 64)   0           add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 16, 16, 64)   36928       activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 16, 16, 64)   256         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 16, 16, 64)   0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 16, 16, 64)   36928       activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 16, 16, 64)   256         conv2d_76[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 16, 16, 64)   0           activation_67[0][0]
#                                                                  batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 16, 16, 64)   0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 128)    73856       activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 128)    512         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 8, 8, 128)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 128)    8320        activation_69[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 128)    147584      activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 128)    512         conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 128)    512         conv2d_78[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 8, 8, 128)    0           batch_normalization_79[0][0]
#                                                                  batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 128)    0           add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 128)    147584      activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 128)    512         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 8, 8, 128)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 128)    147584      activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 128)    512         conv2d_81[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 8, 8, 128)    0           activation_71[0][0]
#                                                                  batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 8, 8, 128)    0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 128)    147584      activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 128)    512         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 8, 8, 128)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 128)    147584      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 128)    512         conv2d_83[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 8, 8, 128)    0           activation_73[0][0]
#                                                                  batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 128)    0           add_35[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 128)    0           activation_75[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 128)          0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100)          12900       flatten_3[0][0]
# ==================================================================================================
# Total params: 1,100,900
# Trainable params: 1,097,764
# Non-trainable params: 3,136
# __________________________________________________________________________________________________
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.momentum
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-3.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-3.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-5.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-5.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-7.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-7.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-8.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-9.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-9.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-10.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-10.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-11.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-11.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-12.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-12.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-13.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-13.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-14.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-14.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-15.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-15.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-16.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-16.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-17.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-17.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-18.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-18.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-19.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-19.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-20.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-20.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-21.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-21.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-22.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-22.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-23.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-23.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-24.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-24.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-25.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-25.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-26.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-26.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-27.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-27.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-28.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-28.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-29.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-29.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-30.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-30.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-31.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-31.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-32.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-32.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-33.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-33.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-34.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-34.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-35.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-35.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-36.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-36.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-37.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-37.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-38.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-38.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-39.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-39.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-40.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-40.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-41.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-41.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-42.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-42.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
# Learning rate 0.035 gave best results with decay 1e-5, accuracy dropped when lr/decay was increased
sgd = optimizers.SGD(lr=0.035, decay=1e-5,momentum=0.8)
adam = optimizers.Adam(lr=0.0006, decay = 1e-3,clipvalue=0.5) #use epoch around 180
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',min_delta=0.0001,patience=5,mode='max')
checkpoint_path = "ResNet18_SGD_BatchNormalization"
best_model = ModelCheckpoint(filepath = checkpoint_path, save_best_only=True, save_weights_only=True, monitor='val_accuracy', mode='max')
# batch size to 128 for best accuracy, it decreases if batch size is increased
history = model.fit(x_train, y_train,
                    batch_size= 128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping,best_model],verbose=2)
# Out:
# Epoch 1/150
# 391/391 - 14s - loss: 4.9924 - accuracy: 0.1308 - val_loss: 5.5032 - val_accuracy: 0.0899
# Epoch 2/150
# 391/391 - 14s - loss: 3.9184 - accuracy: 0.2697 - val_loss: 3.9072 - val_accuracy: 0.2607
# Epoch 3/150
# 391/391 - 14s - loss: 3.2484 - accuracy: 0.3671 - val_loss: 3.7682 - val_accuracy: 0.2775
# Epoch 4/150
# 391/391 - 14s - loss: 2.8341 - accuracy: 0.4390 - val_loss: 3.3561 - val_accuracy: 0.3364
# Epoch 5/150
# 391/391 - 14s - loss: 2.5323 - accuracy: 0.4876 - val_loss: 3.0864 - val_accuracy: 0.3870
# Epoch 6/150
# 391/391 - 13s - loss: 2.3206 - accuracy: 0.5242 - val_loss: 3.7392 - val_accuracy: 0.3302
# Epoch 7/150
# 391/391 - 13s - loss: 2.1428 - accuracy: 0.5609 - val_loss: 2.9885 - val_accuracy: 0.3791
# Epoch 8/150
# 391/391 - 14s - loss: 2.0131 - accuracy: 0.5870 - val_loss: 2.9975 - val_accuracy: 0.4096
# Epoch 9/150
# 391/391 - 13s - loss: 1.9209 - accuracy: 0.6068 - val_loss: 3.5994 - val_accuracy: 0.3510
# Epoch 10/150
# 391/391 - 14s - loss: 1.8301 - accuracy: 0.6333 - val_loss: 2.8745 - val_accuracy: 0.4372
# Epoch 11/150
# 391/391 - 13s - loss: 1.7651 - accuracy: 0.6528 - val_loss: 2.9616 - val_accuracy: 0.4186
# Epoch 12/150
# 391/391 - 14s - loss: 1.7111 - accuracy: 0.6665 - val_loss: 2.8430 - val_accuracy: 0.4559
# Epoch 13/150
# 391/391 - 13s - loss: 1.6653 - accuracy: 0.6828 - val_loss: 2.8843 - val_accuracy: 0.4351
# Epoch 14/150
# 391/391 - 13s - loss: 1.6086 - accuracy: 0.7036 - val_loss: 3.3825 - val_accuracy: 0.3975
# Epoch 15/150
# 391/391 - 14s - loss: 1.5857 - accuracy: 0.7120 - val_loss: 2.8935 - val_accuracy: 0.4638
# Epoch 16/150
# 391/391 - 13s - loss: 1.5622 - accuracy: 0.7276 - val_loss: 3.1210 - val_accuracy: 0.4464
# Epoch 17/150
# 391/391 - 13s - loss: 1.5292 - accuracy: 0.7402 - val_loss: 3.1894 - val_accuracy: 0.4240
# Epoch 18/150
# 391/391 - 13s - loss: 1.5158 - accuracy: 0.7477 - val_loss: 3.1075 - val_accuracy: 0.4584
# Epoch 19/150
# 391/391 - 13s - loss: 1.4936 - accuracy: 0.7571 - val_loss: 4.3879 - val_accuracy: 0.3544
# Epoch 20/150
# 391/391 - 13s - loss: 1.4793 - accuracy: 0.7667 - val_loss: 3.5504 - val_accuracy: 0.4330

# %%
#plot Accuracy vs epochs
train_metrics = history.history['accuracy']
val_metrics = history.history['val_accuracy']
epochs = range(1, len(train_metrics) + 1)
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["training accuracy", 'test accuracy'])
plt.show()
#plot Validaiton loss vs epochs
train_metrics = history.history['loss']
val_metrics = history.history['val_loss']
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["training loss", 'test loss'])
plt.show()

# %%
model = create_model()
# checkpoint_path = "../weights/ResNet18_SGD_BatchNormalization"
checkpoint_path = "ResNet18_SGD_BatchNormalization"
model.load_weights(checkpoint_path)
# loss,acc = model.evaluate(x_test,  y_test, verbose=2)
# print('Test Accuracy:', acc)
cm = confusion_matrix(y_test.argmax(axis=1), model.predict(x_test).argmax(-1))
print(cm)
precision = precision_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1), average='weighted')

accuracy= accuracy_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1))
recall= recall_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1), average='weighted')

print('precision:', precision)
print('accuracy:', accuracy)
print('recall:', recall)
# Out:
# [[81  1  3 ...  0  0  0]
#  [ 0 52  2 ...  0  0  2]
#  [ 2  0 64 ...  0  0  0]
#  ...
#  [ 0  0  1 ... 19  0  0]
#  [ 2  1 15 ...  0 18  1]
#  [ 0  0  0 ...  0  0 67]]
# precision: 0.6028707445340685
# accuracy: 0.4638
# recall: 0.4638
