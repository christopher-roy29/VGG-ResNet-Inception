# %%
import numpy as np
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Conv2D, AveragePooling2D, Dropout, Activation, Flatten
from keras.layers import BatchNormalization, add, Input
from keras import optimizers
from keras import regularizers
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Model
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score,accuracy_score,recall_score,confusion_matrix

# %% [markdown]
# ## Data Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train = x_train.astype('float32') /255
x_test = x_test.astype('float32') /255
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)
# Mean normalization
mean = np.mean(x_train, axis=0)
x_train -= mean
x_test -= mean
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step

# %%
print(x_train.shape[-3:],y_train.shape)
# Out:
# (32, 32, 3) (50000, 100)

# %% [markdown]
# ## Building the Model

# %%
def residual_layer(input,filters,strides,kernel=3):
  model = Conv2D(filters,kernel_size=kernel,strides=strides,padding='same',kernel_regularizer=regularizers.l2(0.001))
  model = model(input)
  return model

# %%
# check for batch_normalization layer added back to back in residual layer
def create_model():
    inp = Input(shape=x_train.shape[-3:])
    m1_res = residual_layer(input=inp,filters=32,strides=1)
    m1_res = Activation('relu')(m1_res)
    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.4)(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=2)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.4)(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = residual_layer(input=m1_res,filters=64,strides=2,kernel=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=2)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = residual_layer(input=m1_res,filters=128,strides=2,kernel=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.4)(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.4)(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m1_res = AveragePooling2D(pool_size=8)(m1_res)
    m2 = Flatten()(m1_res)
    m2 = Dropout(0.4)(m2)
    m2 = Dense(100,activation='softmax')(m2)
    model = Model(inputs=inp,outputs=m2)
    return model

# %%
model = create_model()
model.summary()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   9248        activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   9248        dropout[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 32)   0           activation[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           activation_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 32)   9248        dropout_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 32)   0           activation_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   18496       activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 64)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   2112        activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 64)   0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 64)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   36928       dropout_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 64)   0           activation_8[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 64)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 64)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   36928       dropout_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 64)   0           activation_10[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    73856       activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 128)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 128)    0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 128)    8320        activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    147584      dropout_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 128)    0           conv2d_16[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 128)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 128)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 8, 8, 128)    0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 128)    147584      dropout_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 128)    0           activation_14[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 128)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 128)    147584      activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 128)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 8, 8, 128)    0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    147584      dropout_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 128)    0           activation_16[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 128)    0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 128)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 128)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128)          0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          12900       dropout_9[0][0]
# ==================================================================================================
# Total params: 1,094,628
# Trainable params: 1,094,628
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Learning rate 0.035 gave best results with decay 1e-5, accuracy dropped when lr/decay was increased
sgd = optimizers.SGD(lr=0.035, decay=1e-5,momentum=0.8)
adam = optimizers.Adam(lr=0.0006, decay = 1e-3,clipvalue=0.5) #use epoch around 180
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',min_delta=0.0001,patience=20,mode='max')
checkpoint_path = "ResNet18_SGD_Dropouts"
best_model = ModelCheckpoint(filepath = checkpoint_path, save_best_only=True, save_weights_only=True, monitor='val_accuracy', mode='max')
# batch size to 128 for best accuracy, it decreases if batch size is increased
history = model.fit(x_train, y_train,
                    batch_size= 128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping,best_model],verbose=2)
# Out:
# Epoch 1/150
# 391/391 - 19s - loss: 5.7679 - accuracy: 0.0185 - val_loss: 5.4698 - val_accuracy: 0.0281
# Epoch 2/150
# 391/391 - 19s - loss: 5.2445 - accuracy: 0.0373 - val_loss: 4.9489 - val_accuracy: 0.0645
# Epoch 3/150
# 391/391 - 19s - loss: 4.8377 - accuracy: 0.0584 - val_loss: 4.5762 - val_accuracy: 0.0850
# Epoch 4/150
# 391/391 - 19s - loss: 4.5418 - accuracy: 0.0814 - val_loss: 4.3347 - val_accuracy: 0.1044
# Epoch 5/150
# 391/391 - 20s - loss: 4.3114 - accuracy: 0.0973 - val_loss: 4.1435 - val_accuracy: 0.1253
# Epoch 6/150
# 391/391 - 20s - loss: 4.1245 - accuracy: 0.1163 - val_loss: 3.9114 - val_accuracy: 0.1470
# Epoch 7/150
# 391/391 - 20s - loss: 3.9706 - accuracy: 0.1312 - val_loss: 3.7594 - val_accuracy: 0.1744
# Epoch 8/150
# 391/391 - 20s - loss: 3.8428 - accuracy: 0.1500 - val_loss: 3.6561 - val_accuracy: 0.1869
# Epoch 9/150
# 391/391 - 20s - loss: 3.7218 - accuracy: 0.1675 - val_loss: 3.5797 - val_accuracy: 0.1929
# Epoch 10/150
# 391/391 - 20s - loss: 3.6269 - accuracy: 0.1842 - val_loss: 3.4243 - val_accuracy: 0.2189
# Epoch 11/150
# 391/391 - 20s - loss: 3.5344 - accuracy: 0.2004 - val_loss: 3.4321 - val_accuracy: 0.2204
# Epoch 12/150
# 391/391 - 21s - loss: 3.4479 - accuracy: 0.2149 - val_loss: 3.2261 - val_accuracy: 0.2688
# Epoch 13/150
# 391/391 - 21s - loss: 3.3733 - accuracy: 0.2340 - val_loss: 3.1640 - val_accuracy: 0.2761
# Epoch 14/150
# 391/391 - 20s - loss: 3.3076 - accuracy: 0.2468 - val_loss: 3.0984 - val_accuracy: 0.2951
# Epoch 15/150
# 391/391 - 21s - loss: 3.2394 - accuracy: 0.2607 - val_loss: 3.0664 - val_accuracy: 0.3051
# Epoch 16/150
# 391/391 - 21s - loss: 3.1903 - accuracy: 0.2750 - val_loss: 2.9391 - val_accuracy: 0.3312
# Epoch 17/150
# 391/391 - 21s - loss: 3.1317 - accuracy: 0.2910 - val_loss: 2.8589 - val_accuracy: 0.3530
# Epoch 18/150
# 391/391 - 21s - loss: 3.0623 - accuracy: 0.3052 - val_loss: 2.8250 - val_accuracy: 0.3623
# Epoch 19/150
# 391/391 - 20s - loss: 3.0352 - accuracy: 0.3140 - val_loss: 2.8599 - val_accuracy: 0.3577
# Epoch 20/150
# 391/391 - 21s - loss: 2.3750 - accuracy: 0.5429 - val_loss: 2.3796 - val_accuracy: 0.5518
# Epoch 68/150
# 391/391 - 20s - loss: 2.3655 - accuracy: 0.5460 - val_loss: 2.3652 - val_accuracy: 0.5540
# Epoch 69/150
# 391/391 - 20s - loss: 2.3725 - accuracy: 0.5445 - val_loss: 2.3925 - val_accuracy: 0.5480
# Epoch 70/150
# 391/391 - 20s - loss: 2.3709 - accuracy: 0.5463 - val_loss: 2.3629 - val_accuracy: 0.5612
# Epoch 71/150
# 391/391 - 21s - loss: 2.3712 - accuracy: 0.5467 - val_loss: 2.2942 - val_accuracy: 0.5729
# Epoch 72/150
# 391/391 - 20s - loss: 2.3716 - accuracy: 0.5468 - val_loss: 2.4452 - val_accuracy: 0.5371
# Epoch 73/150
# 391/391 - 20s - loss: 2.3545 - accuracy: 0.5513 - val_loss: 2.4312 - val_accuracy: 0.5385
# Epoch 74/150
# 391/391 - 20s - loss: 2.3483 - accuracy: 0.5536 - val_loss: 2.3257 - val_accuracy: 0.5662
# Epoch 75/150
# 391/391 - 20s - loss: 2.3565 - accuracy: 0.5508 - val_loss: 2.3567 - val_accuracy: 0.5528
# Epoch 76/150
# 391/391 - 20s - loss: 2.3485 - accuracy: 0.5531 - val_loss: 2.3563 - val_accuracy: 0.5582
# Epoch 77/150
# 391/391 - 20s - loss: 2.3355 - accuracy: 0.5570 - val_loss: 2.4206 - val_accuracy: 0.5462
# Epoch 78/150
# 391/391 - 20s - loss: 2.3412 - accuracy: 0.5583 - val_loss: 2.3683 - val_accuracy: 0.5600
# Epoch 79/150
# 391/391 - 20s - loss: 2.3403 - accuracy: 0.5594 - val_loss: 2.3569 - val_accuracy: 0.5632
# Epoch 80/150
# 391/391 - 20s - loss: 2.3296 - accuracy: 0.5603 - val_loss: 2.3470 - val_accuracy: 0.5605
# Epoch 81/150
# 391/391 - 20s - loss: 2.3390 - accuracy: 0.5590 - val_loss: 2.3531 - val_accuracy: 0.5581
# Epoch 82/150
# 391/391 - 21s - loss: 2.3297 - accuracy: 0.5625 - val_loss: 2.4451 - val_accuracy: 0.5449
# Epoch 83/150
# 391/391 - 21s - loss: 2.3274 - accuracy: 0.5632 - val_loss: 2.3213 - val_accuracy: 0.5694
# Epoch 84/150
# 391/391 - 20s - loss: 2.3255 - accuracy: 0.5632 - val_loss: 2.3555 - val_accuracy: 0.5578
# Epoch 85/150
# 391/391 - 20s - loss: 2.3208 - accuracy: 0.5667 - val_loss: 2.3712 - val_accuracy: 0.5582
# Epoch 86/150
# 391/391 - 20s - loss: 2.3165 - accuracy: 0.5682 - val_loss: 2.3620 - val_accuracy: 0.5636
# Epoch 87/150
# 391/391 - 21s - loss: 2.3138 - accuracy: 0.5694 - val_loss: 2.4527 - val_accuracy: 0.5421
# Epoch 88/150
# 391/391 - 20s - loss: 2.3162 - accuracy: 0.5707 - val_loss: 2.3331 - val_accuracy: 0.5660
# Epoch 89/150
# 391/391 - 20s - loss: 2.3062 - accuracy: 0.5705 - val_loss: 2.4428 - val_accuracy: 0.5523
# Epoch 90/150
# 391/391 - 21s - loss: 2.3001 - accuracy: 0.5725 - val_loss: 2.3085 - val_accuracy: 0.5778
# Epoch 91/150
# 391/391 - 20s - loss: 2.2925 - accuracy: 0.5740 - val_loss: 2.3520 - val_accuracy: 0.5645
# Epoch 92/150
# 391/391 - 21s - loss: 2.2930 - accuracy: 0.5746 - val_loss: 2.4584 - val_accuracy: 0.5510
# Epoch 93/150
# 391/391 - 20s - loss: 2.2998 - accuracy: 0.5721 - val_loss: 2.3349 - val_accuracy: 0.5712
# Epoch 94/150
# 391/391 - 21s - loss: 2.2909 - accuracy: 0.5738 - val_loss: 2.2841 - val_accuracy: 0.5828
# Epoch 95/150
# 391/391 - 20s - loss: 2.2937 - accuracy: 0.5740 - val_loss: 2.3128 - val_accuracy: 0.5720
# Epoch 96/150
# 391/391 - 20s - loss: 2.2852 - accuracy: 0.5743 - val_loss: 2.3297 - val_accuracy: 0.5773
# Epoch 97/150
# 391/391 - 21s - loss: 2.2820 - accuracy: 0.5793 - val_loss: 2.2921 - val_accuracy: 0.5803
# Epoch 98/150
# 391/391 - 21s - loss: 2.2776 - accuracy: 0.5807 - val_loss: 2.3040 - val_accuracy: 0.5787
# Epoch 99/150
# 391/391 - 21s - loss: 2.2765 - accuracy: 0.5820 - val_loss: 2.2828 - val_accuracy: 0.5858
# Epoch 100/150
# 391/391 - 20s - loss: 2.2855 - accuracy: 0.5807 - val_loss: 2.2919 - val_accuracy: 0.5819
# Epoch 101/150
# 391/391 - 20s - loss: 2.2693 - accuracy: 0.5832 - val_loss: 2.3410 - val_accuracy: 0.5682
# Epoch 102/150
# 391/391 - 21s - loss: 2.2701 - accuracy: 0.5810 - val_loss: 2.3071 - val_accuracy: 0.5793
# Epoch 103/150
# 391/391 - 21s - loss: 2.2725 - accuracy: 0.5831 - val_loss: 2.3326 - val_accuracy: 0.5694
# Epoch 104/150
# 391/391 - 21s - loss: 2.2706 - accuracy: 0.5829 - val_loss: 2.3193 - val_accuracy: 0.5738
# Epoch 105/150
# 391/391 - 20s - loss: 2.2597 - accuracy: 0.5867 - val_loss: 2.3353 - val_accuracy: 0.5692
# Epoch 106/150
# 391/391 - 20s - loss: 2.2708 - accuracy: 0.5837 - val_loss: 2.3467 - val_accuracy: 0.5739
# Epoch 107/150
# 391/391 - 21s - loss: 2.2540 - accuracy: 0.5909 - val_loss: 2.2916 - val_accuracy: 0.5814
# Epoch 108/150
# 391/391 - 20s - loss: 2.2573 - accuracy: 0.5854 - val_loss: 2.3336 - val_accuracy: 0.5680
# Epoch 109/150
# 391/391 - 21s - loss: 2.2534 - accuracy: 0.5879 - val_loss: 2.3306 - val_accuracy: 0.5769
# Epoch 110/150
# 391/391 - 21s - loss: 2.2408 - accuracy: 0.5926 - val_loss: 2.4150 - val_accuracy: 0.5555
# Epoch 111/150
# 391/391 - 21s - loss: 2.2540 - accuracy: 0.5902 - val_loss: 2.2887 - val_accuracy: 0.5846
# Epoch 112/150
# 391/391 - 21s - loss: 2.2413 - accuracy: 0.5927 - val_loss: 2.3007 - val_accuracy: 0.5873
# Epoch 113/150
# 391/391 - 20s - loss: 2.2322 - accuracy: 0.5960 - val_loss: 2.3622 - val_accuracy: 0.5685
# Epoch 114/150
# 391/391 - 20s - loss: 2.2336 - accuracy: 0.5947 - val_loss: 2.3808 - val_accuracy: 0.5637
# Epoch 115/150
# 391/391 - 21s - loss: 2.2347 - accuracy: 0.5950 - val_loss: 2.3379 - val_accuracy: 0.5722
# Epoch 116/150
# 391/391 - 20s - loss: 2.2318 - accuracy: 0.5969 - val_loss: 2.2842 - val_accuracy: 0.5864
# Epoch 117/150
# 391/391 - 20s - loss: 2.2240 - accuracy: 0.6000 - val_loss: 2.3396 - val_accuracy: 0.5742
# Epoch 118/150
# 391/391 - 20s - loss: 2.2262 - accuracy: 0.5989 - val_loss: 2.3010 - val_accuracy: 0.5811
# Epoch 119/150
# 391/391 - 20s - loss: 2.2250 - accuracy: 0.5974 - val_loss: 2.3022 - val_accuracy: 0.5828
# Epoch 120/150
# 391/391 - 20s - loss: 2.2301 - accuracy: 0.6003 - val_loss: 2.3451 - val_accuracy: 0.5730
# Epoch 121/150
# 391/391 - 20s - loss: 2.2220 - accuracy: 0.6016 - val_loss: 2.3157 - val_accuracy: 0.5843
# Epoch 122/150
# 391/391 - 20s - loss: 2.2291 - accuracy: 0.5972 - val_loss: 2.3078 - val_accuracy: 0.5862
# Epoch 123/150
# 391/391 - 20s - loss: 2.2364 - accuracy: 0.5981 - val_loss: 2.2895 - val_accuracy: 0.5848
# Epoch 124/150
# 391/391 - 20s - loss: 2.2136 - accuracy: 0.6004 - val_loss: 2.3125 - val_accuracy: 0.5834
# Epoch 125/150
# 391/391 - 20s - loss: 2.2114 - accuracy: 0.6015 - val_loss: 2.3891 - val_accuracy: 0.5660
# Epoch 126/150
# 391/391 - 20s - loss: 2.2082 - accuracy: 0.6030 - val_loss: 2.3173 - val_accuracy: 0.5798
# Epoch 127/150
# 391/391 - 20s - loss: 2.2053 - accuracy: 0.6047 - val_loss: 2.3246 - val_accuracy: 0.5755
# Epoch 128/150
# 391/391 - 20s - loss: 2.2127 - accuracy: 0.6050 - val_loss: 2.3041 - val_accuracy: 0.5854
# Epoch 129/150
# 391/391 - 20s - loss: 2.2091 - accuracy: 0.6025 - val_loss: 2.3369 - val_accuracy: 0.5827
# Epoch 130/150
# 391/391 - 20s - loss: 2.2081 - accuracy: 0.6028 - val_loss: 2.3309 - val_accuracy: 0.5810
# Epoch 131/150
# 391/391 - 20s - loss: 2.1990 - accuracy: 0.6081 - val_loss: 2.3345 - val_accuracy: 0.5770
# Epoch 132/150
# 391/391 - 20s - loss: 2.1978 - accuracy: 0.6078 - val_loss: 2.2799 - val_accuracy: 0.5896
# Epoch 133/150
# 391/391 - 20s - loss: 2.2027 - accuracy: 0.6062 - val_loss: 2.4549 - val_accuracy: 0.5538
# Epoch 134/150
# 391/391 - 20s - loss: 2.1940 - accuracy: 0.6073 - val_loss: 2.2956 - val_accuracy: 0.5882
# Epoch 135/150
# 391/391 - 20s - loss: 2.2002 - accuracy: 0.6084 - val_loss: 2.3463 - val_accuracy: 0.5809
# Epoch 136/150
# 391/391 - 20s - loss: 2.1907 - accuracy: 0.6110 - val_loss: 2.2727 - val_accuracy: 0.5938
# Epoch 137/150
# 391/391 - 20s - loss: 2.1859 - accuracy: 0.6111 - val_loss: 2.2797 - val_accuracy: 0.5903
# Epoch 138/150
# 391/391 - 20s - loss: 2.2017 - accuracy: 0.6079 - val_loss: 2.2851 - val_accuracy: 0.5826
# Epoch 139/150
# 391/391 - 20s - loss: 2.1719 - accuracy: 0.6153 - val_loss: 2.2552 - val_accuracy: 0.5955
# Epoch 140/150
# 391/391 - 20s - loss: 2.1878 - accuracy: 0.6114 - val_loss: 2.3452 - val_accuracy: 0.5782
# Epoch 141/150
# 391/391 - 20s - loss: 2.1754 - accuracy: 0.6151 - val_loss: 2.2624 - val_accuracy: 0.5978
# Epoch 142/150
# 391/391 - 20s - loss: 2.1745 - accuracy: 0.6158 - val_loss: 2.3899 - val_accuracy: 0.5683
# Epoch 143/150
# 391/391 - 20s - loss: 2.1907 - accuracy: 0.6076 - val_loss: 2.2699 - val_accuracy: 0.5948
# Epoch 144/150
# 391/391 - 20s - loss: 2.1731 - accuracy: 0.6170 - val_loss: 2.3345 - val_accuracy: 0.5831
# Epoch 145/150
# 391/391 - 20s - loss: 2.1715 - accuracy: 0.6155 - val_loss: 2.3460 - val_accuracy: 0.5755
# Epoch 146/150
# 391/391 - 20s - loss: 2.1702 - accuracy: 0.6173 - val_loss: 2.3357 - val_accuracy: 0.5839
# Epoch 147/150
# 391/391 - 20s - loss: 2.1766 - accuracy: 0.6163 - val_loss: 2.3151 - val_accuracy: 0.5832
# Epoch 148/150
# 391/391 - 20s - loss: 2.1673 - accuracy: 0.6156 - val_loss: 2.3073 - val_accuracy: 0.5832
# Epoch 149/150
# 391/391 - 20s - loss: 2.1680 - accuracy: 0.6177 - val_loss: 2.2728 - val_accuracy: 0.5959
# Epoch 150/150
# 391/391 - 20s - loss: 2.1679 - accuracy: 0.6184 - val_loss: 2.2821 - val_accuracy: 0.5937

# %%
#plot Accuracy vs epochs
train_metrics = history.history['accuracy']
val_metrics = history.history['val_accuracy']
epochs = range(1, len(train_metrics) + 1)
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["training accuracy", 'test accuracy'])
plt.show()
#plot Validaiton loss vs epochs
train_metrics = history.history['loss']
val_metrics = history.history['val_loss']
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["training loss", 'test loss'])
plt.show()

# %%
model = create_model()
# checkpoint_path = "../weights/ResNet18_SGD_Dropouts"
checkpoint_path = "ResNet18_SGD_Dropouts"
model.load_weights(checkpoint_path)
# loss,acc = model.evaluate(x_test,  y_test, verbose=2)
# print('Test Accuracy:', acc)
cm = confusion_matrix(y_test.argmax(axis=1), model.predict(x_test).argmax(-1))
print(cm)
precision = precision_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1), average='weighted')

accuracy= accuracy_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1))
recall= recall_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1), average='weighted')

print('precision:', precision)
print('accuracy:', accuracy)
print('recall:', recall)
# Out:
# [[82  0  0 ...  0  0  0]
#  [ 0 78  0 ...  0  0  1]
#  [ 0  0 39 ...  0  6  0]
#  ...
#  [ 0  0  0 ... 63  1  0]
#  [ 0  1  3 ...  0 47  1]
#  [ 0  0  0 ...  0  0 69]]
# precision: 0.6103797180095645
# accuracy: 0.5978
# recall: 0.5978
