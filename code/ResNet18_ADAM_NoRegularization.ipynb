# %%
import numpy as np
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Conv2D, AveragePooling2D, Dropout, Activation, Flatten
from keras.layers import BatchNormalization, add, Input
from keras import optimizers
from keras import regularizers
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Model
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score,accuracy_score,recall_score,confusion_matrix

# %% [markdown]
# ## Data Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train = x_train.astype('float32') /255
x_test = x_test.astype('float32') /255
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)
# Mean normalization
mean = np.mean(x_train, axis=0)
x_train -= mean
x_test -= mean
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 6s 0us/step

# %%
print(x_train.shape[-3:],y_train.shape)
# Out:
# (32, 32, 3) (50000, 100)

# %% [markdown]
# ## Building the Model

# %%
def residual_layer(input,filters,strides,kernel=3):
  model = Conv2D(filters,kernel_size=kernel,strides=strides,padding='same')
  model = model(input)
  return model

# %%
# check for batch_normalization layer added back to back in residual layer
def create_model():
    inp = Input(shape=x_train.shape[-3:])
    m1_res = residual_layer(input=inp,filters=32,strides=1)
    m1_res = Activation('relu')(m1_res)
    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=2)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = residual_layer(input=m1_res,filters=64,strides=2,kernel=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=2)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = residual_layer(input=m1_res,filters=128,strides=2,kernel=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=1)
    m2 = Activation('relu')(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m1_res = AveragePooling2D(pool_size=8)(m1_res)
    m2 = Flatten()(m1_res)
    m2 = Dense(100,activation='softmax')(m2)
    model = Model(inputs=inp,outputs=m2)
    return model

# %%
model = create_model()
model.summary()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   9248        activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   9248        activation_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 32)   0           activation[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9248        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           activation_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 32)   9248        activation_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 32)   0           activation_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   18496       activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   2112        activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 64)   0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   36928       activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 64)   0           activation_8[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 64)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 64)   0           activation_10[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    73856       activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 128)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 128)    8320        activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    147584      activation_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 128)    0           conv2d_16[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 128)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 128)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 128)    147584      activation_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 128)    0           activation_14[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 128)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 128)    147584      activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 128)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    147584      activation_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 128)    0           activation_16[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 128)    0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 128)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 128)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          12900       flatten[0][0]
# ==================================================================================================
# Total params: 1,094,628
# Trainable params: 1,094,628
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Learning rate 0.035 gave best results with decay 1e-5, accuracy dropped when lr/decay was increased
sgd = optimizers.SGD(lr=0.035, decay=1e-5,momentum=0.8)
adam = optimizers.Adam(lr=0.0006, decay = 1e-3,clipvalue=0.5) #use epoch around 180
model.compile(loss='categorical_crossentropy', optimizer=adam,metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',min_delta=0.0001,patience=10,mode='max')
checkpoint_path = "ResNet18_ADAM_NoRegularization"
best_model = ModelCheckpoint(filepath = checkpoint_path, save_best_only=True, save_weights_only=True, monitor='val_accuracy', mode='max')
# batch size to 128 for best accuracy, it decreases if batch size is increased
history = model.fit(x_train, y_train,
                    batch_size= 128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping,best_model],verbose=2)
# Out:
# Epoch 1/150
# 391/391 - 18s - loss: 4.2202 - accuracy: 0.0434 - val_loss: 3.8998 - val_accuracy: 0.0837
# Epoch 2/150
# 391/391 - 18s - loss: 3.7256 - accuracy: 0.1138 - val_loss: 3.5703 - val_accuracy: 0.1532
# Epoch 3/150
# 391/391 - 18s - loss: 3.3938 - accuracy: 0.1818 - val_loss: 3.2741 - val_accuracy: 0.2114
# Epoch 4/150
# 391/391 - 18s - loss: 3.1001 - accuracy: 0.2373 - val_loss: 3.0257 - val_accuracy: 0.2538
# Epoch 5/150
# 391/391 - 18s - loss: 2.8818 - accuracy: 0.2815 - val_loss: 2.8778 - val_accuracy: 0.2876
# Epoch 6/150
# 391/391 - 18s - loss: 2.6993 - accuracy: 0.3148 - val_loss: 2.7080 - val_accuracy: 0.3211
# Epoch 7/150
# 391/391 - 18s - loss: 2.5463 - accuracy: 0.3459 - val_loss: 2.6915 - val_accuracy: 0.3221
# Epoch 8/150
# 391/391 - 18s - loss: 2.4189 - accuracy: 0.3740 - val_loss: 2.5632 - val_accuracy: 0.3484
# Epoch 9/150
# 391/391 - 18s - loss: 2.3078 - accuracy: 0.3968 - val_loss: 2.4855 - val_accuracy: 0.3633
# Epoch 10/150
# 391/391 - 18s - loss: 2.2190 - accuracy: 0.4133 - val_loss: 2.4303 - val_accuracy: 0.3770
# Epoch 11/150
# 391/391 - 18s - loss: 2.1331 - accuracy: 0.4347 - val_loss: 2.3749 - val_accuracy: 0.3868
# Epoch 12/150
# 391/391 - 18s - loss: 2.0586 - accuracy: 0.4471 - val_loss: 2.3626 - val_accuracy: 0.3958
# Epoch 13/150
# 391/391 - 18s - loss: 1.9898 - accuracy: 0.4663 - val_loss: 2.3475 - val_accuracy: 0.4021
# Epoch 14/150
# 391/391 - 18s - loss: 1.9310 - accuracy: 0.4803 - val_loss: 2.3153 - val_accuracy: 0.4052
# Epoch 15/150
# 391/391 - 18s - loss: 1.8711 - accuracy: 0.4908 - val_loss: 2.3122 - val_accuracy: 0.4160
# Epoch 16/150
# 391/391 - 18s - loss: 1.8213 - accuracy: 0.5037 - val_loss: 2.2722 - val_accuracy: 0.4176
# Epoch 17/150
# 391/391 - 18s - loss: 1.7679 - accuracy: 0.5178 - val_loss: 2.2557 - val_accuracy: 0.4242
# Epoch 18/150
# 391/391 - 18s - loss: 1.7250 - accuracy: 0.5258 - val_loss: 2.2466 - val_accuracy: 0.4268
# Epoch 19/150
# 391/391 - 18s - loss: 1.6846 - accuracy: 0.5368 - val_loss: 2.2645 - val_accuracy: 0.4271
# Epoch 20/150
# 391/391 - 18s - loss: 1.6445 - accuracy: 0.5472 - val_loss: 2.2268 - val_accuracy: 0.4356
# Epoch 21/150
# 391/391 - 18s - loss: 1.6092 - accuracy: 0.5549 - val_loss: 2.2417 - val_accuracy: 0.4323
# Epoch 22/150
# 391/391 - 18s - loss: 1.5716 - accuracy: 0.5660 - val_loss: 2.2462 - val_accuracy: 0.4327
# Epoch 23/150
# 391/391 - 18s - loss: 1.5413 - accuracy: 0.5734 - val_loss: 2.2369 - val_accuracy: 0.4377
# Epoch 24/150
# 391/391 - 18s - loss: 1.5115 - accuracy: 0.5805 - val_loss: 2.2573 - val_accuracy: 0.4335
# Epoch 25/150
# 391/391 - 18s - loss: 1.4808 - accuracy: 0.5878 - val_loss: 2.2298 - val_accuracy: 0.4380
# Epoch 26/150
# 391/391 - 18s - loss: 1.4489 - accuracy: 0.5973 - val_loss: 2.2691 - val_accuracy: 0.4408
# Epoch 27/150
# 391/391 - 18s - loss: 1.4227 - accuracy: 0.6018 - val_loss: 2.2570 - val_accuracy: 0.4397
# Epoch 28/150
# 391/391 - 18s - loss: 1.4011 - accuracy: 0.6090 - val_loss: 2.2739 - val_accuracy: 0.4448
# Epoch 29/150
# 391/391 - 18s - loss: 1.3707 - accuracy: 0.6159 - val_loss: 2.2887 - val_accuracy: 0.4406
# Epoch 30/150
# 391/391 - 18s - loss: 1.3437 - accuracy: 0.6232 - val_loss: 2.2808 - val_accuracy: 0.4430
# Epoch 31/150
# 391/391 - 18s - loss: 1.3184 - accuracy: 0.6309 - val_loss: 2.2919 - val_accuracy: 0.4449
# Epoch 32/150
# 391/391 - 18s - loss: 1.2990 - accuracy: 0.6345 - val_loss: 2.3152 - val_accuracy: 0.4432
# Epoch 33/150
# 391/391 - 18s - loss: 1.2762 - accuracy: 0.6419 - val_loss: 2.2986 - val_accuracy: 0.4479
# Epoch 34/150
# 391/391 - 18s - loss: 1.2519 - accuracy: 0.6483 - val_loss: 2.3266 - val_accuracy: 0.4467
# Epoch 35/150
# 391/391 - 18s - loss: 1.2308 - accuracy: 0.6536 - val_loss: 2.3334 - val_accuracy: 0.4496
# Epoch 36/150
# 391/391 - 18s - loss: 1.2117 - accuracy: 0.6590 - val_loss: 2.3424 - val_accuracy: 0.4488
# Epoch 37/150
# 391/391 - 18s - loss: 1.1860 - accuracy: 0.6673 - val_loss: 2.3437 - val_accuracy: 0.4477
# Epoch 38/150
# 391/391 - 18s - loss: 1.1709 - accuracy: 0.6690 - val_loss: 2.3439 - val_accuracy: 0.4502
# Epoch 39/150
# 391/391 - 18s - loss: 1.1503 - accuracy: 0.6758 - val_loss: 2.4008 - val_accuracy: 0.4438
# Epoch 40/150
# 391/391 - 18s - loss: 1.1303 - accuracy: 0.6809 - val_loss: 2.3774 - val_accuracy: 0.4481
# Epoch 41/150
# 391/391 - 18s - loss: 1.1153 - accuracy: 0.6855 - val_loss: 2.3950 - val_accuracy: 0.4481
# Epoch 42/150
# 391/391 - 18s - loss: 1.0955 - accuracy: 0.6908 - val_loss: 2.4246 - val_accuracy: 0.4417
# Epoch 43/150
# 391/391 - 18s - loss: 1.0804 - accuracy: 0.6948 - val_loss: 2.4144 - val_accuracy: 0.4508
# Epoch 44/150
# 391/391 - 18s - loss: 1.0597 - accuracy: 0.7007 - val_loss: 2.4487 - val_accuracy: 0.4453
# Epoch 45/150
# 391/391 - 18s - loss: 1.0481 - accuracy: 0.7037 - val_loss: 2.4775 - val_accuracy: 0.4529
# Epoch 46/150
# 391/391 - 18s - loss: 1.0275 - accuracy: 0.7096 - val_loss: 2.4688 - val_accuracy: 0.4477
# Epoch 47/150
# 391/391 - 18s - loss: 1.0114 - accuracy: 0.7139 - val_loss: 2.5205 - val_accuracy: 0.4442
# Epoch 48/150
# 391/391 - 18s - loss: 0.9985 - accuracy: 0.7186 - val_loss: 2.5618 - val_accuracy: 0.4452
# Epoch 49/150
# 391/391 - 18s - loss: 0.9788 - accuracy: 0.7248 - val_loss: 2.5400 - val_accuracy: 0.4430
# Epoch 50/150
# 391/391 - 18s - loss: 0.9679 - accuracy: 0.7259 - val_loss: 2.5855 - val_accuracy: 0.4485
# Epoch 51/150
# 391/391 - 18s - loss: 0.9538 - accuracy: 0.7320 - val_loss: 2.5427 - val_accuracy: 0.4462
# Epoch 52/150
# 391/391 - 18s - loss: 0.9370 - accuracy: 0.7354 - val_loss: 2.6135 - val_accuracy: 0.4478
# Epoch 53/150
# 391/391 - 18s - loss: 0.9241 - accuracy: 0.7402 - val_loss: 2.6006 - val_accuracy: 0.4489
# Epoch 54/150
# 391/391 - 18s - loss: 0.9080 - accuracy: 0.7447 - val_loss: 2.6118 - val_accuracy: 0.4454
# Epoch 55/150
# 391/391 - 18s - loss: 0.8939 - accuracy: 0.7480 - val_loss: 2.6423 - val_accuracy: 0.4431

# %%
#plot Accuracy vs epochs
train_metrics = history.history['accuracy']
val_metrics = history.history['val_accuracy']
epochs = range(1, len(train_metrics) + 1)
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["training accuracy", 'test accuracy'])
plt.show()
#plot Validaiton loss vs epochs
train_metrics = history.history['loss']
val_metrics = history.history['val_loss']
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["training loss", 'test loss'])
plt.show()

# %%
model = create_model()
# checkpoint_path = "../weights/ResNet18_ADAM_NoRegularization"
checkpoint_path = "ResNet18_ADAM_NoRegularization"
model.load_weights(checkpoint_path)
# loss,acc = model.evaluate(x_test,  y_test, verbose=2)
# print('Test Accuracy:', acc)
cm = confusion_matrix(y_test.argmax(axis=1), model.predict(x_test).argmax(-1))
print(cm)
precision = precision_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1), average='weighted')

accuracy= accuracy_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1))
recall= recall_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1), average='weighted')

print('precision:', precision)
print('accuracy:', accuracy)
print('recall:', recall)
# Out:
# [[70  1  0 ...  0  0  0]
#  [ 0 62  0 ...  0  0  1]
#  [ 0  1 39 ...  1  6  0]
#  ...
#  [ 0  0  0 ... 42  0  0]
#  [ 0  1  8 ...  1 18  1]
#  [ 1  1  0 ...  1  0 50]]
# precision: 0.4500079847061923
# accuracy: 0.4529
# recall: 0.4529
