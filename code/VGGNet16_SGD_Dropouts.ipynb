# %%
import numpy as np
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Activation, Flatten
from keras.layers import BatchNormalization
from keras import optimizers
from keras import regularizers
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score,accuracy_score,recall_score,confusion_matrix

# %% [markdown]
# ## Data Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train = x_train.astype('float32') /255
x_test = x_test.astype('float32') /255
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)
# Mean normalization
mean = np.mean(x_train, axis=0)
x_train -= mean
x_test -= mean
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step

# %%
print(x_train.shape[-3:],y_train.shape)
# Out:
# (32, 32, 3) (50000, 100)

# %% [markdown]
# ## Building the Model

# %%
def create_model():
    model = Sequential()

    model.add(Conv2D(64, (3, 3), padding='same',
                      input_shape=x_train.shape[-3:],kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))

    model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))
    model.add(Dropout(0.3))

    model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))
    model.add(Dropout(0.3))

    model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2, 2)))
    # model.add(Dropout(0.5))

    model.add(Flatten())
    model.add(Dense(512,kernel_regularizer=regularizers.l2(0.001)))
    model.add(Activation('relu'))

    model.add(Dropout(0.4))
    model.add(Dense(100))
    model.add(Activation('softmax'))
    return model

# %%
model = create_model()
model.summary()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_8 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_9 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# activation_10 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               51300
# _________________________________________________________________
# activation_11 (Activation)   (None, 100)               0
# =================================================================
# Total params: 8,735,652
# Trainable params: 8,735,652
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Learning rate 0.035 gave best results with decay 1e-5, accuracy dropped when lr/decay was increased
sgd = optimizers.SGD(lr=0.035, decay=1e-5,momentum=0.8) #epochs=150
adam = optimizers.Adam(lr=0.001, decay = 1e-3) #epochs=80
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',min_delta=0.0001,patience=20,mode='max')
checkpoint_path = "VGGNet16_SGD_Dropouts"
best_model = ModelCheckpoint(filepath = checkpoint_path, save_best_only=True,save_weights_only=True, monitor='val_accuracy', mode='max')
# batch size to 128 for best accuracy, it decreases if batch size is increased
history = model.fit(x_train, y_train,
                    batch_size= 128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping,best_model],verbose=2)
# Out:
# Epoch 1/150
# 391/391 - 18s - loss: 7.3587 - accuracy: 0.0123 - val_loss: 6.9899 - val_accuracy: 0.0166
# Epoch 2/150
# 391/391 - 17s - loss: 6.5661 - accuracy: 0.0246 - val_loss: 6.1704 - val_accuracy: 0.0346
# Epoch 3/150
# 391/391 - 17s - loss: 5.8876 - accuracy: 0.0442 - val_loss: 5.6342 - val_accuracy: 0.0549
# Epoch 4/150
# 391/391 - 18s - loss: 5.3986 - accuracy: 0.0577 - val_loss: 5.1456 - val_accuracy: 0.0776
# Epoch 5/150
# 391/391 - 18s - loss: 4.9857 - accuracy: 0.0743 - val_loss: 4.7907 - val_accuracy: 0.0939
# Epoch 6/150
# 391/391 - 18s - loss: 4.6811 - accuracy: 0.0848 - val_loss: 4.4978 - val_accuracy: 0.1098
# Epoch 7/150
# 391/391 - 18s - loss: 4.4522 - accuracy: 0.0969 - val_loss: 4.3284 - val_accuracy: 0.1143
# Epoch 8/150
# 391/391 - 18s - loss: 4.2691 - accuracy: 0.1092 - val_loss: 4.2690 - val_accuracy: 0.1085
# Epoch 9/150
# 391/391 - 18s - loss: 4.1079 - accuracy: 0.1238 - val_loss: 3.9906 - val_accuracy: 0.1422
# Epoch 10/150
# 391/391 - 18s - loss: 3.9689 - accuracy: 0.1374 - val_loss: 3.8876 - val_accuracy: 0.1570
# Epoch 11/150
# 391/391 - 18s - loss: 3.8532 - accuracy: 0.1531 - val_loss: 3.7778 - val_accuracy: 0.1681
# Epoch 12/150
# 391/391 - 18s - loss: 3.7520 - accuracy: 0.1639 - val_loss: 3.7505 - val_accuracy: 0.1728
# Epoch 13/150
# 391/391 - 18s - loss: 3.6573 - accuracy: 0.1812 - val_loss: 3.5290 - val_accuracy: 0.2062
# Epoch 14/150
# 391/391 - 18s - loss: 3.5586 - accuracy: 0.1975 - val_loss: 3.4589 - val_accuracy: 0.2219
# Epoch 15/150
# 391/391 - 18s - loss: 3.4762 - accuracy: 0.2139 - val_loss: 3.4096 - val_accuracy: 0.2287
# Epoch 16/150
# 391/391 - 18s - loss: 3.4098 - accuracy: 0.2300 - val_loss: 3.2795 - val_accuracy: 0.2647
# Epoch 17/150
# 391/391 - 18s - loss: 3.3318 - accuracy: 0.2490 - val_loss: 3.2846 - val_accuracy: 0.2643
# Epoch 18/150
# 391/391 - 18s - loss: 3.2573 - accuracy: 0.2641 - val_loss: 3.2142 - val_accuracy: 0.2881
# Epoch 19/150
# 391/391 - 18s - loss: 3.2014 - accuracy: 0.2801 - val_loss: 3.1048 - val_accuracy: 0.3018
# Epoch 20/150
# 391/391 - 18s - loss: 3.1448 - accuracy: 0.2942 - val_loss: 3.0721 - val_accuracy: 0.3102
# Epoch 21/150
# 391/391 - 18s - loss: 3.0897 - accuracy: 0.3120 - val_loss: 2.9979 - val_accuracy: 0.3311
# Epoch 22/150
# 391/391 - 18s - loss: 3.0402 - accuracy: 0.3260 - val_loss: 2.9873 - val_accuracy: 0.3482
# Epoch 23/150
# 391/391 - 18s - loss: 2.9805 - accuracy: 0.3431 - val_loss: 2.8980 - val_accuracy: 0.3602
# Epoch 24/150
# 391/391 - 18s - loss: 2.9276 - accuracy: 0.3617 - val_loss: 3.0198 - val_accuracy: 0.3532
# Epoch 25/150
# 391/391 - 18s - loss: 2.8945 - accuracy: 0.3740 - val_loss: 3.0126 - val_accuracy: 0.3626
# Epoch 26/150
# 391/391 - 18s - loss: 2.8397 - accuracy: 0.3924 - val_loss: 2.8885 - val_accuracy: 0.3872
# Epoch 27/150
# 391/391 - 18s - loss: 2.8013 - accuracy: 0.4040 - val_loss: 2.8055 - val_accuracy: 0.4139
# Epoch 28/150
# 391/391 - 18s - loss: 2.7705 - accuracy: 0.4191 - val_loss: 2.7499 - val_accuracy: 0.4386
# Epoch 29/150
# 391/391 - 18s - loss: 2.7356 - accuracy: 0.4297 - val_loss: 2.9955 - val_accuracy: 0.3914
# Epoch 30/150
# 391/391 - 18s - loss: 2.7081 - accuracy: 0.4425 - val_loss: 2.7802 - val_accuracy: 0.4427
# Epoch 31/150
# 391/391 - 18s - loss: 2.6682 - accuracy: 0.4557 - val_loss: 2.7902 - val_accuracy: 0.4321
# Epoch 32/150
# 391/391 - 18s - loss: 2.6508 - accuracy: 0.4631 - val_loss: 2.7772 - val_accuracy: 0.4481
# Epoch 33/150
# 391/391 - 18s - loss: 2.6162 - accuracy: 0.4776 - val_loss: 2.7702 - val_accuracy: 0.4564
# Epoch 34/150
# 391/391 - 18s - loss: 2.5842 - accuracy: 0.4917 - val_loss: 2.8320 - val_accuracy: 0.4557
# Epoch 35/150
# 391/391 - 18s - loss: 2.5749 - accuracy: 0.5004 - val_loss: 2.6613 - val_accuracy: 0.4895
# Epoch 36/150
# 391/391 - 18s - loss: 2.5597 - accuracy: 0.5069 - val_loss: 2.8923 - val_accuracy: 0.4472
# Epoch 37/150
# 391/391 - 18s - loss: 2.5443 - accuracy: 0.5128 - val_loss: 2.7150 - val_accuracy: 0.4848
# Epoch 38/150
# 391/391 - 18s - loss: 2.5233 - accuracy: 0.5247 - val_loss: 2.7210 - val_accuracy: 0.4873
# Epoch 39/150
# 391/391 - 18s - loss: 2.5172 - accuracy: 0.5316 - val_loss: 2.6506 - val_accuracy: 0.5113
# Epoch 40/150
# 391/391 - 18s - loss: 2.4967 - accuracy: 0.5401 - val_loss: 2.6970 - val_accuracy: 0.5074
# Epoch 41/150
# 391/391 - 18s - loss: 2.4959 - accuracy: 0.5440 - val_loss: 2.6955 - val_accuracy: 0.5062
# Epoch 42/150
# 391/391 - 18s - loss: 2.4818 - accuracy: 0.5520 - val_loss: 2.8027 - val_accuracy: 0.4915
# Epoch 43/150
# 391/391 - 18s - loss: 2.4662 - accuracy: 0.5595 - val_loss: 2.7163 - val_accuracy: 0.5171
# Epoch 44/150
# 391/391 - 18s - loss: 2.4490 - accuracy: 0.5690 - val_loss: 2.7674 - val_accuracy: 0.5125
# Epoch 45/150
# 391/391 - 18s - loss: 2.4568 - accuracy: 0.5672 - val_loss: 2.7561 - val_accuracy: 0.5186
# Epoch 46/150
# 391/391 - 18s - loss: 2.4498 - accuracy: 0.5725 - val_loss: 2.8840 - val_accuracy: 0.4920
# Epoch 47/150
# 391/391 - 18s - loss: 2.4400 - accuracy: 0.5793 - val_loss: 2.8658 - val_accuracy: 0.5004
# Epoch 48/150
# 391/391 - 18s - loss: 2.4357 - accuracy: 0.5847 - val_loss: 2.8835 - val_accuracy: 0.5039
# Epoch 49/150
# 391/391 - 18s - loss: 2.4265 - accuracy: 0.5910 - val_loss: 2.6954 - val_accuracy: 0.5399
# Epoch 50/150
# 391/391 - 18s - loss: 2.4178 - accuracy: 0.5922 - val_loss: 2.7444 - val_accuracy: 0.5355
# Epoch 51/150
# 391/391 - 18s - loss: 2.4171 - accuracy: 0.5963 - val_loss: 2.8492 - val_accuracy: 0.5169
# Epoch 52/150
# 391/391 - 18s - loss: 2.4172 - accuracy: 0.6017 - val_loss: 2.7883 - val_accuracy: 0.5303
# Epoch 53/150
# 391/391 - 18s - loss: 2.4091 - accuracy: 0.6069 - val_loss: 2.7538 - val_accuracy: 0.5366
# Epoch 54/150
# 391/391 - 18s - loss: 2.3947 - accuracy: 0.6144 - val_loss: 2.9511 - val_accuracy: 0.5039
# Epoch 55/150
# 391/391 - 18s - loss: 2.3976 - accuracy: 0.6167 - val_loss: 2.7580 - val_accuracy: 0.5492
# Epoch 56/150
# 391/391 - 18s - loss: 2.3927 - accuracy: 0.6197 - val_loss: 2.8359 - val_accuracy: 0.5417
# Epoch 57/150
# 391/391 - 18s - loss: 2.3943 - accuracy: 0.6238 - val_loss: 2.8438 - val_accuracy: 0.5440
# Epoch 58/150
# 391/391 - 18s - loss: 2.3785 - accuracy: 0.6305 - val_loss: 2.8584 - val_accuracy: 0.5369
# Epoch 59/150
# 391/391 - 18s - loss: 2.3937 - accuracy: 0.6294 - val_loss: 2.9518 - val_accuracy: 0.5205
# Epoch 60/150
# 391/391 - 18s - loss: 2.3943 - accuracy: 0.6352 - val_loss: 2.8589 - val_accuracy: 0.5427
# Epoch 61/150
# 391/391 - 18s - loss: 2.3851 - accuracy: 0.6374 - val_loss: 2.8942 - val_accuracy: 0.5420
# Epoch 62/150
# 391/391 - 18s - loss: 2.3843 - accuracy: 0.6412 - val_loss: 2.8186 - val_accuracy: 0.5502
# Epoch 63/150
# 391/391 - 18s - loss: 2.3740 - accuracy: 0.6476 - val_loss: 2.9183 - val_accuracy: 0.5398
# Epoch 64/150
# 391/391 - 18s - loss: 2.3844 - accuracy: 0.6467 - val_loss: 2.8814 - val_accuracy: 0.5477
# Epoch 65/150
# 391/391 - 18s - loss: 2.3929 - accuracy: 0.6468 - val_loss: 2.9931 - val_accuracy: 0.5310
# Epoch 66/150
# 391/391 - 18s - loss: 2.3865 - accuracy: 0.6557 - val_loss: 2.8915 - val_accuracy: 0.5543
# Epoch 67/150
# 391/391 - 18s - loss: 2.3688 - accuracy: 0.6596 - val_loss: 2.9634 - val_accuracy: 0.5371
# Epoch 68/150
# 391/391 - 18s - loss: 2.3716 - accuracy: 0.6628 - val_loss: 2.9574 - val_accuracy: 0.5486
# Epoch 69/150
# 391/391 - 18s - loss: 2.3834 - accuracy: 0.6592 - val_loss: 2.9849 - val_accuracy: 0.5425
# Epoch 70/150
# 391/391 - 18s - loss: 2.3810 - accuracy: 0.6662 - val_loss: 2.9332 - val_accuracy: 0.5537
# Epoch 71/150
# 391/391 - 18s - loss: 2.3871 - accuracy: 0.6654 - val_loss: 2.9757 - val_accuracy: 0.5482
# Epoch 72/150
# 391/391 - 18s - loss: 2.3793 - accuracy: 0.6698 - val_loss: 2.9745 - val_accuracy: 0.5524
# Epoch 73/150
# 391/391 - 18s - loss: 2.3790 - accuracy: 0.6729 - val_loss: 2.9502 - val_accuracy: 0.5584
# Epoch 74/150
# 391/391 - 18s - loss: 2.3797 - accuracy: 0.6738 - val_loss: 3.0067 - val_accuracy: 0.5516
# Epoch 75/150
# 391/391 - 18s - loss: 2.3731 - accuracy: 0.6781 - val_loss: 3.0537 - val_accuracy: 0.5486
# Epoch 76/150
# 391/391 - 18s - loss: 2.3884 - accuracy: 0.6744 - val_loss: 3.0489 - val_accuracy: 0.5437
# Epoch 77/150
# 391/391 - 18s - loss: 2.3771 - accuracy: 0.6816 - val_loss: 3.0241 - val_accuracy: 0.5569
# Epoch 78/150
# 391/391 - 18s - loss: 2.3833 - accuracy: 0.6849 - val_loss: 3.0527 - val_accuracy: 0.5509
# Epoch 79/150
# 391/391 - 18s - loss: 2.3807 - accuracy: 0.6872 - val_loss: 3.0297 - val_accuracy: 0.5573
# Epoch 80/150
# 391/391 - 18s - loss: 2.3863 - accuracy: 0.6861 - val_loss: 2.9821 - val_accuracy: 0.5613
# Epoch 81/150
# 391/391 - 18s - loss: 2.3830 - accuracy: 0.6907 - val_loss: 3.0688 - val_accuracy: 0.5562
# Epoch 82/150
# 391/391 - 18s - loss: 2.3682 - accuracy: 0.6957 - val_loss: 3.1010 - val_accuracy: 0.5468
# Epoch 83/150
# 391/391 - 18s - loss: 2.3828 - accuracy: 0.6945 - val_loss: 3.0915 - val_accuracy: 0.5555
# Epoch 84/150
# 391/391 - 18s - loss: 2.3801 - accuracy: 0.6961 - val_loss: 3.0533 - val_accuracy: 0.5593
# Epoch 85/150
# 391/391 - 18s - loss: 2.3753 - accuracy: 0.7002 - val_loss: 3.1278 - val_accuracy: 0.5547
# Epoch 86/150
# 391/391 - 18s - loss: 2.3788 - accuracy: 0.7006 - val_loss: 3.1188 - val_accuracy: 0.5586
# Epoch 87/150
# 391/391 - 18s - loss: 2.3779 - accuracy: 0.7046 - val_loss: 3.1509 - val_accuracy: 0.5489
# Epoch 88/150
# 391/391 - 18s - loss: 2.3799 - accuracy: 0.7041 - val_loss: 3.1349 - val_accuracy: 0.5504
# Epoch 89/150
# 391/391 - 18s - loss: 2.3877 - accuracy: 0.7058 - val_loss: 3.1036 - val_accuracy: 0.5653
# Epoch 90/150
# 391/391 - 18s - loss: 2.3779 - accuracy: 0.7124 - val_loss: 3.0758 - val_accuracy: 0.5644
# Epoch 91/150
# 391/391 - 18s - loss: 2.3799 - accuracy: 0.7102 - val_loss: 3.1585 - val_accuracy: 0.5444
# Epoch 92/150
# 391/391 - 18s - loss: 2.3831 - accuracy: 0.7089 - val_loss: 3.2084 - val_accuracy: 0.5488
# Epoch 93/150
# 391/391 - 18s - loss: 2.3786 - accuracy: 0.7127 - val_loss: 3.1441 - val_accuracy: 0.5580
# Epoch 94/150
# 391/391 - 18s - loss: 2.3778 - accuracy: 0.7147 - val_loss: 3.0879 - val_accuracy: 0.5691
# Epoch 95/150
# 391/391 - 18s - loss: 2.3718 - accuracy: 0.7184 - val_loss: 3.1713 - val_accuracy: 0.5594
# Epoch 96/150
# 391/391 - 18s - loss: 2.3714 - accuracy: 0.7206 - val_loss: 3.0992 - val_accuracy: 0.5729
# Epoch 97/150
# 391/391 - 18s - loss: 2.3730 - accuracy: 0.7208 - val_loss: 3.1423 - val_accuracy: 0.5697
# Epoch 98/150
# 391/391 - 18s - loss: 2.3728 - accuracy: 0.7223 - val_loss: 3.1481 - val_accuracy: 0.5667
# Epoch 99/150
# 391/391 - 18s - loss: 2.3675 - accuracy: 0.7258 - val_loss: 3.1784 - val_accuracy: 0.5601
# Epoch 100/150
# 391/391 - 18s - loss: 2.3618 - accuracy: 0.7278 - val_loss: 3.2099 - val_accuracy: 0.5589
# Epoch 101/150
# 391/391 - 18s - loss: 2.3738 - accuracy: 0.7231 - val_loss: 3.1609 - val_accuracy: 0.5690
# Epoch 102/150
# 391/391 - 18s - loss: 2.3766 - accuracy: 0.7246 - val_loss: 3.1658 - val_accuracy: 0.5591
# Epoch 103/150
# 391/391 - 18s - loss: 2.3660 - accuracy: 0.7263 - val_loss: 3.2312 - val_accuracy: 0.5574
# Epoch 104/150
# 391/391 - 18s - loss: 2.3730 - accuracy: 0.7307 - val_loss: 3.2292 - val_accuracy: 0.5603
# Epoch 105/150
# 391/391 - 18s - loss: 2.3765 - accuracy: 0.7303 - val_loss: 3.1888 - val_accuracy: 0.5587
# Epoch 106/150
# 391/391 - 18s - loss: 2.3723 - accuracy: 0.7316 - val_loss: 3.3194 - val_accuracy: 0.5474
# Epoch 107/150
# 391/391 - 18s - loss: 2.3779 - accuracy: 0.7324 - val_loss: 3.2466 - val_accuracy: 0.5639
# Epoch 108/150
# 391/391 - 18s - loss: 2.3677 - accuracy: 0.7365 - val_loss: 3.2067 - val_accuracy: 0.5718
# Epoch 109/150
# 391/391 - 18s - loss: 2.3714 - accuracy: 0.7356 - val_loss: 3.2917 - val_accuracy: 0.5505
# Epoch 110/150
# 391/391 - 18s - loss: 2.3758 - accuracy: 0.7352 - val_loss: 3.2540 - val_accuracy: 0.5639
# Epoch 111/150
# 391/391 - 18s - loss: 2.3747 - accuracy: 0.7359 - val_loss: 3.2095 - val_accuracy: 0.5699
# Epoch 112/150
# 391/391 - 18s - loss: 2.3596 - accuracy: 0.7444 - val_loss: 3.2614 - val_accuracy: 0.5630
# Epoch 113/150
# 391/391 - 18s - loss: 2.3735 - accuracy: 0.7397 - val_loss: 3.1997 - val_accuracy: 0.5712
# Epoch 114/150
# 391/391 - 18s - loss: 2.3643 - accuracy: 0.7420 - val_loss: 3.2802 - val_accuracy: 0.5634
# Epoch 115/150
# 391/391 - 18s - loss: 2.3660 - accuracy: 0.7418 - val_loss: 3.2923 - val_accuracy: 0.5595
# Epoch 116/150
# 391/391 - 18s - loss: 2.3715 - accuracy: 0.7416 - val_loss: 3.2820 - val_accuracy: 0.5643

# %%
#plot Accuracy vs epochs
train_metrics = history.history['accuracy']
val_metrics = history.history['val_accuracy']
epochs = range(1, len(train_metrics) + 1)
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["training accuracy", 'test accuracy'])
plt.show()
#plot Validaiton loss vs epochs
train_metrics = history.history['loss']
val_metrics = history.history['val_loss']
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["training loss", 'test loss'])
plt.show()

# %%
model = create_model()
# checkpoint_path = "../weights/VGGNet16_SGD_Dropouts"
checkpoint_path = "VGGNet16_SGD_Dropouts"
model.load_weights(checkpoint_path)
# loss,acc = model.evaluate(x_test,  y_test, verbose=2)
# print('Test Accuracy:', acc)
prediction = model.predict(x_test).argmax(-1)
cm = confusion_matrix(y_test.argmax(axis=1), prediction)
np.set_printoptions(threshold=5000)
print(cm)
precision = precision_score(y_test.argmax(axis=1), prediction, average='weighted')

accuracy= accuracy_score(y_test.argmax(axis=1), prediction)
recall= recall_score(y_test.argmax(axis=1), prediction, average='weighted')

print('precision:', precision)
print('accuracy:', accuracy)
print('recall:', recall)
# Out:
# [[89  0  1 ...  0  0  0]
#  [ 0 71  0 ...  0  0  1]
#  [ 1  3 39 ...  1  5  0]
#  ...
#  [ 0  0  1 ... 53  0  0]
#  [ 0  0  4 ...  0 30  1]
#  [ 0  0  0 ...  0  0 61]]
# precision: 0.5805243402705044
# accuracy: 0.5729
# recall: 0.5729
