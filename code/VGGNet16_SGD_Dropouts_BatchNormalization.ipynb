# %%
import numpy as np
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Activation, Flatten
from keras.layers import BatchNormalization
from keras import optimizers
from keras import regularizers
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score,accuracy_score,recall_score,confusion_matrix

# %% [markdown]
# ## Data Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train = x_train.astype('float32') /255
x_test = x_test.astype('float32') /255
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)
# Mean normalization
mean = np.mean(x_train, axis=0)
x_train -= mean
x_test -= mean
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 6s 0us/step

# %%
print(x_train.shape[-3:],y_train.shape)
# Out:
# (32, 32, 3) (50000, 100)

# %% [markdown]
# ## Building the Model

# %%
def create_model():
    model = Sequential()

    model.add(Conv2D(64, (3, 3), padding='same',
                      input_shape=x_train.shape[-3:],kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.3))

    model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.4))

    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPool2D(pool_size=(2, 2)))
    # model.add(Dropout(0.5))

    model.add(Flatten())
    model.add(Dense(512,kernel_regularizer=regularizers.l2(0.001)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Dropout(0.5))
    model.add(Dense(100))
    model.add(Activation('softmax'))
    return model

# %%
model = create_model()
model.summary()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_10 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               51300
# _________________________________________________________________
# activation_11 (Activation)   (None, 100)               0
# =================================================================
# Total params: 8,748,452
# Trainable params: 8,742,052
# Non-trainable params: 6,400
# _________________________________________________________________

# %%
# Learning rate 0.035 gave best results with decay 1e-5, accuracy dropped when lr/decay was increased
sgd = optimizers.SGD(lr=0.035, decay=1e-5,momentum=0.8) #epochs=150
adam = optimizers.Adam(lr=0.001, decay = 1e-3) #epochs=80
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',min_delta=0.0001,patience=20,mode='max')
checkpoint_path = "VGGNet16_SGD_Dropouts_BatchNormalization"
best_model = ModelCheckpoint(filepath = checkpoint_path, save_best_only=True,save_weights_only=True, monitor='val_accuracy', mode='max')
# batch size to 128 for best accuracy, it decreases if batch size is increased
history = model.fit(x_train, y_train,
                    batch_size= 128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping,best_model],verbose=2)
# Out:
# Epoch 1/150
# 391/391 - 14s - loss: 7.6634 - accuracy: 0.0210 - val_loss: 7.2547 - val_accuracy: 0.0137
# Epoch 2/150
# 391/391 - 13s - loss: 6.3416 - accuracy: 0.0822 - val_loss: 6.4948 - val_accuracy: 0.0564
# Epoch 3/150
# 391/391 - 13s - loss: 5.3664 - accuracy: 0.1451 - val_loss: 5.3784 - val_accuracy: 0.1296
# Epoch 4/150
# 391/391 - 13s - loss: 4.6657 - accuracy: 0.2108 - val_loss: 4.7984 - val_accuracy: 0.1689
# Epoch 5/150
# 391/391 - 13s - loss: 4.0979 - accuracy: 0.2737 - val_loss: 3.9225 - val_accuracy: 0.2982
# Epoch 6/150
# 391/391 - 13s - loss: 3.6719 - accuracy: 0.3243 - val_loss: 3.9004 - val_accuracy: 0.2792
# Epoch 7/150
# 391/391 - 13s - loss: 3.3455 - accuracy: 0.3686 - val_loss: 3.5102 - val_accuracy: 0.3396
# Epoch 8/150
# 391/391 - 13s - loss: 3.1154 - accuracy: 0.4039 - val_loss: 3.1650 - val_accuracy: 0.3925
# Epoch 9/150
# 391/391 - 13s - loss: 2.9395 - accuracy: 0.4348 - val_loss: 3.2650 - val_accuracy: 0.3767
# Epoch 10/150
# 391/391 - 13s - loss: 2.8081 - accuracy: 0.4542 - val_loss: 3.0979 - val_accuracy: 0.4114
# Epoch 11/150
# 391/391 - 13s - loss: 2.6989 - accuracy: 0.4774 - val_loss: 3.0585 - val_accuracy: 0.4174
# Epoch 12/150
# 391/391 - 13s - loss: 2.6180 - accuracy: 0.4960 - val_loss: 2.8590 - val_accuracy: 0.4481
# Epoch 13/150
# 391/391 - 13s - loss: 2.5736 - accuracy: 0.5081 - val_loss: 2.7662 - val_accuracy: 0.4692
# Epoch 14/150
# 391/391 - 13s - loss: 2.5236 - accuracy: 0.5223 - val_loss: 2.6917 - val_accuracy: 0.4905
# Epoch 15/150
# 391/391 - 13s - loss: 2.4827 - accuracy: 0.5347 - val_loss: 2.9289 - val_accuracy: 0.4504
# Epoch 16/150
# 391/391 - 13s - loss: 2.4500 - accuracy: 0.5482 - val_loss: 3.0770 - val_accuracy: 0.4331
# Epoch 17/150
# 391/391 - 13s - loss: 2.4309 - accuracy: 0.5567 - val_loss: 2.7952 - val_accuracy: 0.4806
# Epoch 18/150
# 391/391 - 13s - loss: 2.4235 - accuracy: 0.5640 - val_loss: 3.3597 - val_accuracy: 0.4170
# Epoch 19/150
# 391/391 - 13s - loss: 2.4049 - accuracy: 0.5739 - val_loss: 2.9243 - val_accuracy: 0.4842
# Epoch 20/150
# 391/391 - 13s - loss: 2.3881 - accuracy: 0.5813 - val_loss: 3.0267 - val_accuracy: 0.4710
# Epoch 21/150
# 391/391 - 13s - loss: 2.3877 - accuracy: 0.5868 - val_loss: 2.7586 - val_accuracy: 0.5186
# Epoch 22/150
# 391/391 - 13s - loss: 2.3844 - accuracy: 0.5948 - val_loss: 2.6921 - val_accuracy: 0.5381
# Epoch 23/150
# 391/391 - 13s - loss: 2.3880 - accuracy: 0.5987 - val_loss: 3.0962 - val_accuracy: 0.4750
# Epoch 24/150
# 391/391 - 13s - loss: 2.3838 - accuracy: 0.6050 - val_loss: 3.0117 - val_accuracy: 0.4908
# Epoch 25/150
# 391/391 - 13s - loss: 2.3845 - accuracy: 0.6096 - val_loss: 3.0112 - val_accuracy: 0.4887
# Epoch 26/150
# 391/391 - 13s - loss: 2.3837 - accuracy: 0.6176 - val_loss: 3.0827 - val_accuracy: 0.4858
# Epoch 27/150
# 391/391 - 13s - loss: 2.3759 - accuracy: 0.6211 - val_loss: 3.7154 - val_accuracy: 0.4101
# Epoch 28/150
# 391/391 - 13s - loss: 2.3880 - accuracy: 0.6225 - val_loss: 3.1230 - val_accuracy: 0.4885
# Epoch 29/150
# 391/391 - 13s - loss: 2.3874 - accuracy: 0.6290 - val_loss: 3.0481 - val_accuracy: 0.5075
# Epoch 30/150
# 391/391 - 13s - loss: 2.3832 - accuracy: 0.6324 - val_loss: 3.2992 - val_accuracy: 0.4739
# Epoch 31/150
# 391/391 - 13s - loss: 2.3942 - accuracy: 0.6356 - val_loss: 2.9625 - val_accuracy: 0.5324
# Epoch 32/150
# 391/391 - 13s - loss: 2.3904 - accuracy: 0.6409 - val_loss: 3.3075 - val_accuracy: 0.4731
# Epoch 33/150
# 391/391 - 13s - loss: 2.3946 - accuracy: 0.6446 - val_loss: 3.0173 - val_accuracy: 0.5287
# Epoch 34/150
# 391/391 - 13s - loss: 2.4006 - accuracy: 0.6461 - val_loss: 2.9687 - val_accuracy: 0.5344
# Epoch 35/150
# 391/391 - 13s - loss: 2.4130 - accuracy: 0.6477 - val_loss: 3.4027 - val_accuracy: 0.4678
# Epoch 36/150
# 391/391 - 13s - loss: 2.4096 - accuracy: 0.6519 - val_loss: 3.1113 - val_accuracy: 0.5152
# Epoch 37/150
# 391/391 - 13s - loss: 2.4199 - accuracy: 0.6522 - val_loss: 3.0136 - val_accuracy: 0.5358
# Epoch 38/150
# 391/391 - 13s - loss: 2.4175 - accuracy: 0.6583 - val_loss: 3.1885 - val_accuracy: 0.5189
# Epoch 39/150
# 391/391 - 13s - loss: 2.4175 - accuracy: 0.6596 - val_loss: 3.2142 - val_accuracy: 0.5105
# Epoch 40/150
# 391/391 - 13s - loss: 2.4229 - accuracy: 0.6630 - val_loss: 3.1971 - val_accuracy: 0.5168
# Epoch 41/150
# 391/391 - 13s - loss: 2.4203 - accuracy: 0.6671 - val_loss: 3.1388 - val_accuracy: 0.5258
# Epoch 42/150
# 391/391 - 13s - loss: 2.4189 - accuracy: 0.6707 - val_loss: 3.2179 - val_accuracy: 0.5319

# %%
#plot Accuracy vs epochs
train_metrics = history.history['accuracy']
val_metrics = history.history['val_accuracy']
epochs = range(1, len(train_metrics) + 1)
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["training accuracy", 'test accuracy'])
plt.show()
#plot Validaiton loss vs epochs
train_metrics = history.history['loss']
val_metrics = history.history['val_loss']
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["training loss", 'test loss'])
plt.show()

# %%
model = create_model()
# checkpoint_path = "../weights/VGGNet16_SGD_Dropouts_BatchNormalization"
checkpoint_path = "VGGNet16_SGD_Dropouts_BatchNormalization"
model.load_weights(checkpoint_path)
# loss,acc = model.evaluate(x_test,  y_test, verbose=2)
# print('Test Accuracy:', acc)
prediction = model.predict(x_test).argmax(-1)
cm = confusion_matrix(y_test.argmax(axis=1), prediction)
np.set_printoptions(threshold=5000)
print(cm)
precision = precision_score(y_test.argmax(axis=1), prediction, average='weighted')

accuracy= accuracy_score(y_test.argmax(axis=1), prediction)
recall= recall_score(y_test.argmax(axis=1), prediction, average='weighted')

print('precision:', precision)
print('accuracy:', accuracy)
print('recall:', recall)
# Out:
# [[69  1  0 ...  0  0  0]
#  [ 0 82  0 ...  0  0  0]
#  [ 1  2 24 ...  0 10  0]
#  ...
#  [ 0  1  0 ... 37  1  0]
#  [ 0  1  0 ...  0 39  1]
#  [ 0  1  0 ...  0  0 66]]
# precision: 0.5815407544168293
# accuracy: 0.5381
# recall: 0.5381
