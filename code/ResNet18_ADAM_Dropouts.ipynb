# %%
import numpy as np
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Conv2D, AveragePooling2D, Dropout, Activation, Flatten
from keras.layers import BatchNormalization, add, Input
from keras import optimizers
from keras import regularizers
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Model
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score,accuracy_score,recall_score,confusion_matrix

# %% [markdown]
# ## Data Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train = x_train.astype('float32') /255
x_test = x_test.astype('float32') /255
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)
# Mean normalization
mean = np.mean(x_train, axis=0)
x_train -= mean
x_test -= mean

# %%
print(x_train.shape[-3:],y_train.shape)
# Out:
# (32, 32, 3) (50000, 100)

# %% [markdown]
# ## Building the Model

# %%
def residual_layer(input,filters,strides,kernel=3):
  model = Conv2D(filters,kernel_size=kernel,strides=strides,padding='same')
  model = model(input)
  return model

# %%
def create_model():
    inp = Input(shape=x_train.shape[-3:])
    m1_res = residual_layer(input=inp,filters=32,strides=1)
    m1_res = Activation('relu')(m1_res)
    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=32,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=32,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=2)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = residual_layer(input=m1_res,filters=64,strides=2,kernel=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=64,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=64,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=2)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = residual_layer(input=m1_res,filters=128,strides=2,kernel=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m2 = residual_layer(input=m1_res,filters=128,strides=1)
    m2 = Activation('relu')(m2)
    m2 = Dropout(0.3)(m2)
    m2 = residual_layer(input=m2,filters=128,strides=1)
    m1_res = add([m1_res,m2])
    m1_res = Activation('relu')(m1_res)

    m1_res = AveragePooling2D(pool_size=8)(m1_res)
    m2 = Flatten()(m1_res)
    m2 = Dense(100,activation='softmax')(m2)
    model = Model(inputs=inp,outputs=m2)
    return model

# %%
model = create_model()
model.summary()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "functional_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 32, 32, 32)   896         input_7[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 32, 32, 32)   0           conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 32, 32, 32)   9248        activation_114[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 32, 32, 32)   0           conv2d_127[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 32, 32, 32)   0           activation_115[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 32, 32, 32)   9248        dropout_16[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 32, 32, 32)   0           activation_114[0][0]
#                                                                  conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 32, 32, 32)   0           add_54[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 32, 32, 32)   9248        activation_116[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 32, 32, 32)   0           conv2d_129[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 32, 32, 32)   0           activation_117[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 32, 32, 32)   9248        dropout_17[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 32, 32, 32)   0           activation_116[0][0]
#                                                                  conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 32, 32, 32)   0           add_55[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 32, 32, 32)   9248        activation_118[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 32, 32, 32)   0           conv2d_131[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 32, 32, 32)   0           activation_119[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 32, 32, 32)   9248        dropout_18[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 32, 32, 32)   0           activation_118[0][0]
#                                                                  conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 32, 32, 32)   0           add_56[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 16, 16, 64)   18496       activation_120[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 16, 16, 64)   0           conv2d_133[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 16, 16, 64)   0           activation_121[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 16, 16, 64)   2112        activation_120[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 16, 16, 64)   36928       dropout_19[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 16, 16, 64)   0           conv2d_135[0][0]
#                                                                  conv2d_134[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 16, 16, 64)   0           add_57[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 16, 16, 64)   36928       activation_122[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 16, 16, 64)   0           conv2d_136[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 16, 16, 64)   0           activation_123[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 16, 16, 64)   36928       dropout_20[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 16, 16, 64)   0           activation_122[0][0]
#                                                                  conv2d_137[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 16, 16, 64)   0           add_58[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 16, 16, 64)   36928       activation_124[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 16, 16, 64)   0           conv2d_138[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 16, 16, 64)   0           activation_125[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 16, 16, 64)   36928       dropout_21[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 16, 16, 64)   0           activation_124[0][0]
#                                                                  conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 16, 16, 64)   0           add_59[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 8, 8, 128)    73856       activation_126[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 8, 8, 128)    0           conv2d_140[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 8, 8, 128)    0           activation_127[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 8, 8, 128)    8320        activation_126[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 8, 8, 128)    147584      dropout_22[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 8, 8, 128)    0           conv2d_142[0][0]
#                                                                  conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 8, 8, 128)    0           add_60[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 8, 8, 128)    147584      activation_128[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 8, 8, 128)    0           conv2d_143[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 8, 8, 128)    0           activation_129[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 8, 8, 128)    147584      dropout_23[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 8, 8, 128)    0           activation_128[0][0]
#                                                                  conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 8, 8, 128)    0           add_61[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 8, 8, 128)    147584      activation_130[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 8, 8, 128)    0           conv2d_145[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 8, 8, 128)    0           activation_131[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 8, 8, 128)    147584      dropout_24[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 8, 8, 128)    0           activation_130[0][0]
#                                                                  conv2d_146[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 8, 8, 128)    0           add_62[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 1, 1, 128)    0           activation_132[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 128)          0           average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100)          12900       flatten_6[0][0]
# ==================================================================================================
# Total params: 1,094,628
# Trainable params: 1,094,628
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Learning rate 0.035 gave best results with decay 1e-5, accuracy dropped when lr/decay was increased
sgd = optimizers.SGD(lr=0.035, decay=1e-5,momentum=0.8)
adam = optimizers.Adam(lr=0.0006, decay = 1e-3,clipvalue=0.5) #use epoch around 180
model.compile(loss='categorical_crossentropy', optimizer=adam,metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',min_delta=0.0001,patience=20,mode='max')
checkpoint_path = "ResNet18_ADAM_Dropouts"
best_model = ModelCheckpoint(filepath = checkpoint_path, save_best_only=True, save_weights_only=True, monitor='val_accuracy', mode='max')
# batch size to 128 for best accuracy, it decreases if batch size is increased
history = model.fit(x_train, y_train,
                    batch_size= 128,
                    epochs=150,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping,best_model],verbose=2)
# Out:
# Epoch 1/150
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0268s vs `on_train_batch_end` time: 0.0446s). Check your callbacks.
# 391/391 - 20s - loss: 4.2440 - accuracy: 0.0447 - val_loss: 3.9334 - val_accuracy: 0.0875
# Epoch 2/150
# 391/391 - 21s - loss: 3.7355 - accuracy: 0.1180 - val_loss: 3.5611 - val_accuracy: 0.1570
# Epoch 3/150
# 391/391 - 20s - loss: 3.4158 - accuracy: 0.1775 - val_loss: 3.3131 - val_accuracy: 0.1960
# Epoch 4/150
# 391/391 - 20s - loss: 3.1646 - accuracy: 0.2230 - val_loss: 3.0745 - val_accuracy: 0.2448
# Epoch 5/150
# 391/391 - 20s - loss: 2.9751 - accuracy: 0.2599 - val_loss: 2.9943 - val_accuracy: 0.2600
# Epoch 6/150
# 391/391 - 20s - loss: 2.8227 - accuracy: 0.2921 - val_loss: 2.7905 - val_accuracy: 0.3036
# Epoch 7/150
# 391/391 - 20s - loss: 2.7018 - accuracy: 0.3169 - val_loss: 2.7228 - val_accuracy: 0.3118
# Epoch 8/150
# 391/391 - 20s - loss: 2.6031 - accuracy: 0.3336 - val_loss: 2.6231 - val_accuracy: 0.3304
# Epoch 9/150
# 391/391 - 20s - loss: 2.5138 - accuracy: 0.3521 - val_loss: 2.5928 - val_accuracy: 0.3473
# Epoch 10/150
# 391/391 - 20s - loss: 2.4395 - accuracy: 0.3676 - val_loss: 2.5335 - val_accuracy: 0.3509
# Epoch 11/150
# 391/391 - 20s - loss: 2.3772 - accuracy: 0.3806 - val_loss: 2.4698 - val_accuracy: 0.3670
# Epoch 12/150
# 391/391 - 20s - loss: 2.3196 - accuracy: 0.3922 - val_loss: 2.4200 - val_accuracy: 0.3789
# Epoch 13/150
# 391/391 - 20s - loss: 2.2677 - accuracy: 0.4026 - val_loss: 2.3939 - val_accuracy: 0.3804
# Epoch 14/150
# 391/391 - 20s - loss: 2.2221 - accuracy: 0.4149 - val_loss: 2.3622 - val_accuracy: 0.3949
# Epoch 15/150
# 391/391 - 20s - loss: 2.1768 - accuracy: 0.4244 - val_loss: 2.3215 - val_accuracy: 0.3995
# Epoch 16/150
# 391/391 - 20s - loss: 2.1415 - accuracy: 0.4314 - val_loss: 2.3288 - val_accuracy: 0.4033
# Epoch 17/150
# 391/391 - 20s - loss: 2.1035 - accuracy: 0.4387 - val_loss: 2.2886 - val_accuracy: 0.4103
# Epoch 18/150
# 391/391 - 20s - loss: 2.0670 - accuracy: 0.4476 - val_loss: 2.2602 - val_accuracy: 0.4142
# Epoch 19/150
# 391/391 - 20s - loss: 2.0402 - accuracy: 0.4528 - val_loss: 2.2545 - val_accuracy: 0.4184
# Epoch 20/150
# 391/391 - 20s - loss: 2.0105 - accuracy: 0.4610 - val_loss: 2.1992 - val_accuracy: 0.4287
# Epoch 21/150
# 391/391 - 20s - loss: 1.9908 - accuracy: 0.4656 - val_loss: 2.1984 - val_accuracy: 0.4289
# Epoch 22/150
# 391/391 - 20s - loss: 1.9639 - accuracy: 0.4707 - val_loss: 2.1812 - val_accuracy: 0.4305
# Epoch 23/150
# 391/391 - 20s - loss: 1.9411 - accuracy: 0.4752 - val_loss: 2.2102 - val_accuracy: 0.4302
# Epoch 24/150
# 391/391 - 20s - loss: 1.9211 - accuracy: 0.4827 - val_loss: 2.1630 - val_accuracy: 0.4392
# Epoch 25/150
# 391/391 - 20s - loss: 1.8928 - accuracy: 0.4860 - val_loss: 2.1508 - val_accuracy: 0.4427
# Epoch 26/150
# 391/391 - 20s - loss: 1.8806 - accuracy: 0.4879 - val_loss: 2.1320 - val_accuracy: 0.4433
# Epoch 27/150
# 391/391 - 20s - loss: 1.8691 - accuracy: 0.4934 - val_loss: 2.1169 - val_accuracy: 0.4481
# Epoch 28/150
# 391/391 - 20s - loss: 1.8462 - accuracy: 0.4967 - val_loss: 2.1498 - val_accuracy: 0.4420
# Epoch 29/150
# 391/391 - 20s - loss: 1.8325 - accuracy: 0.4990 - val_loss: 2.1594 - val_accuracy: 0.4393
# Epoch 30/150
# 391/391 - 20s - loss: 1.8222 - accuracy: 0.5020 - val_loss: 2.1342 - val_accuracy: 0.4502
# Epoch 31/150
# 391/391 - 20s - loss: 1.8010 - accuracy: 0.5093 - val_loss: 2.1093 - val_accuracy: 0.4501
# Epoch 32/150
# 391/391 - 20s - loss: 1.7887 - accuracy: 0.5091 - val_loss: 2.1244 - val_accuracy: 0.4516
# Epoch 33/150
# 391/391 - 20s - loss: 1.7785 - accuracy: 0.5125 - val_loss: 2.0973 - val_accuracy: 0.4555
# Epoch 34/150
# 391/391 - 20s - loss: 1.7642 - accuracy: 0.5163 - val_loss: 2.0854 - val_accuracy: 0.4567
# Epoch 35/150
# 391/391 - 20s - loss: 1.7501 - accuracy: 0.5191 - val_loss: 2.0767 - val_accuracy: 0.4623
# Epoch 36/150
# 391/391 - 20s - loss: 1.7314 - accuracy: 0.5224 - val_loss: 2.0819 - val_accuracy: 0.4610
# Epoch 37/150
# 391/391 - 20s - loss: 1.7272 - accuracy: 0.5244 - val_loss: 2.0578 - val_accuracy: 0.4621
# Epoch 38/150
# 391/391 - 20s - loss: 1.7158 - accuracy: 0.5264 - val_loss: 2.0797 - val_accuracy: 0.4638
# Epoch 39/150
# 391/391 - 20s - loss: 1.7036 - accuracy: 0.5308 - val_loss: 2.0781 - val_accuracy: 0.4608
# Epoch 40/150
# 391/391 - 20s - loss: 1.7018 - accuracy: 0.5289 - val_loss: 2.1155 - val_accuracy: 0.4597
# Epoch 41/150
# 391/391 - 20s - loss: 1.6859 - accuracy: 0.5331 - val_loss: 2.0693 - val_accuracy: 0.4684
# Epoch 42/150
# 391/391 - 20s - loss: 1.6749 - accuracy: 0.5379 - val_loss: 2.0519 - val_accuracy: 0.4671
# Epoch 43/150
# 391/391 - 20s - loss: 1.6700 - accuracy: 0.5364 - val_loss: 2.0849 - val_accuracy: 0.4653
# Epoch 44/150
# 391/391 - 20s - loss: 1.6564 - accuracy: 0.5416 - val_loss: 2.0596 - val_accuracy: 0.4699
# Epoch 45/150
# 391/391 - 20s - loss: 1.6502 - accuracy: 0.5425 - val_loss: 2.0527 - val_accuracy: 0.4690
# Epoch 46/150
# 391/391 - 20s - loss: 1.6434 - accuracy: 0.5460 - val_loss: 2.0515 - val_accuracy: 0.4695
# Epoch 47/150
# 391/391 - 20s - loss: 1.6293 - accuracy: 0.5479 - val_loss: 2.0758 - val_accuracy: 0.4720
# Epoch 48/150
# 391/391 - 20s - loss: 1.6302 - accuracy: 0.5468 - val_loss: 2.0562 - val_accuracy: 0.4747
# Epoch 49/150
# 391/391 - 20s - loss: 1.6190 - accuracy: 0.5502 - val_loss: 2.0680 - val_accuracy: 0.4690
# Epoch 50/150
# 391/391 - 20s - loss: 1.6160 - accuracy: 0.5508 - val_loss: 2.0170 - val_accuracy: 0.4767
# Epoch 51/150
# 391/391 - 20s - loss: 1.6069 - accuracy: 0.5533 - val_loss: 2.0255 - val_accuracy: 0.4754
# Epoch 52/150
# 391/391 - 20s - loss: 1.5983 - accuracy: 0.5556 - val_loss: 2.0538 - val_accuracy: 0.4755
# Epoch 53/150
# 391/391 - 20s - loss: 1.5882 - accuracy: 0.5556 - val_loss: 2.0390 - val_accuracy: 0.4788
# Epoch 54/150
# 391/391 - 20s - loss: 1.5809 - accuracy: 0.5594 - val_loss: 2.0656 - val_accuracy: 0.4739
# Epoch 55/150
# 391/391 - 20s - loss: 1.5747 - accuracy: 0.5591 - val_loss: 2.0442 - val_accuracy: 0.4774
# Epoch 56/150
# 391/391 - 20s - loss: 1.5712 - accuracy: 0.5627 - val_loss: 2.0355 - val_accuracy: 0.4792
# Epoch 57/150
# 391/391 - 20s - loss: 1.5695 - accuracy: 0.5626 - val_loss: 2.0345 - val_accuracy: 0.4777
# Epoch 58/150
# 391/391 - 20s - loss: 1.5577 - accuracy: 0.5647 - val_loss: 2.0240 - val_accuracy: 0.4803
# Epoch 59/150
# 391/391 - 20s - loss: 1.5489 - accuracy: 0.5648 - val_loss: 2.0470 - val_accuracy: 0.4773
# Epoch 60/150
# 391/391 - 20s - loss: 1.5473 - accuracy: 0.5668 - val_loss: 2.0219 - val_accuracy: 0.4831
# Epoch 61/150
# 391/391 - 20s - loss: 1.5400 - accuracy: 0.5683 - val_loss: 2.0412 - val_accuracy: 0.4795
# Epoch 62/150
# 391/391 - 20s - loss: 1.5340 - accuracy: 0.5699 - val_loss: 2.0301 - val_accuracy: 0.4850
# Epoch 63/150
# 391/391 - 20s - loss: 1.5261 - accuracy: 0.5721 - val_loss: 2.0367 - val_accuracy: 0.4839
# Epoch 64/150
# 391/391 - 20s - loss: 1.5218 - accuracy: 0.5735 - val_loss: 2.0431 - val_accuracy: 0.4801
# Epoch 65/150
# 391/391 - 20s - loss: 1.5164 - accuracy: 0.5751 - val_loss: 2.0327 - val_accuracy: 0.4815
# Epoch 66/150
# 391/391 - 20s - loss: 1.5100 - accuracy: 0.5761 - val_loss: 2.0242 - val_accuracy: 0.4837
# Epoch 67/150
# 391/391 - 20s - loss: 1.5068 - accuracy: 0.5756 - val_loss: 2.0365 - val_accuracy: 0.4836
# Epoch 68/150
# 391/391 - 20s - loss: 1.5026 - accuracy: 0.5775 - val_loss: 2.0167 - val_accuracy: 0.4843
# Epoch 69/150
# 391/391 - 20s - loss: 1.4932 - accuracy: 0.5809 - val_loss: 2.0215 - val_accuracy: 0.4840
# Epoch 70/150
# 391/391 - 20s - loss: 1.4883 - accuracy: 0.5810 - val_loss: 2.0332 - val_accuracy: 0.4832
# Epoch 71/150
# 391/391 - 20s - loss: 1.4935 - accuracy: 0.5801 - val_loss: 2.0223 - val_accuracy: 0.4856
# Epoch 72/150
# 391/391 - 20s - loss: 1.4830 - accuracy: 0.5821 - val_loss: 2.0144 - val_accuracy: 0.4872
# Epoch 73/150
# 391/391 - 20s - loss: 1.4780 - accuracy: 0.5835 - val_loss: 2.0236 - val_accuracy: 0.4894
# Epoch 74/150
# 391/391 - 20s - loss: 1.4771 - accuracy: 0.5819 - val_loss: 2.0191 - val_accuracy: 0.4879
# Epoch 75/150
# 391/391 - 20s - loss: 1.4719 - accuracy: 0.5831 - val_loss: 2.0049 - val_accuracy: 0.4883
# Epoch 76/150
# 391/391 - 20s - loss: 1.4661 - accuracy: 0.5855 - val_loss: 2.0279 - val_accuracy: 0.4877
# Epoch 77/150
# 391/391 - 20s - loss: 1.4576 - accuracy: 0.5888 - val_loss: 2.0403 - val_accuracy: 0.4872
# Epoch 78/150
# 391/391 - 20s - loss: 1.4557 - accuracy: 0.5906 - val_loss: 2.0093 - val_accuracy: 0.4902
# Epoch 79/150
# 391/391 - 20s - loss: 1.4531 - accuracy: 0.5896 - val_loss: 2.0164 - val_accuracy: 0.4883
# Epoch 80/150
# 391/391 - 20s - loss: 1.4501 - accuracy: 0.5909 - val_loss: 2.0223 - val_accuracy: 0.4882
# Epoch 81/150
# 391/391 - 20s - loss: 1.4478 - accuracy: 0.5893 - val_loss: 2.0219 - val_accuracy: 0.4917
# Epoch 82/150
# 391/391 - 20s - loss: 1.4358 - accuracy: 0.5944 - val_loss: 2.0365 - val_accuracy: 0.4864
# Epoch 83/150
# 391/391 - 20s - loss: 1.4365 - accuracy: 0.5949 - val_loss: 2.0212 - val_accuracy: 0.4894
# Epoch 84/150
# 391/391 - 20s - loss: 1.4327 - accuracy: 0.5926 - val_loss: 2.0197 - val_accuracy: 0.4916
# Epoch 85/150
# 391/391 - 20s - loss: 1.4267 - accuracy: 0.5943 - val_loss: 2.0233 - val_accuracy: 0.4930
# Epoch 86/150
# 391/391 - 20s - loss: 1.4284 - accuracy: 0.5948 - val_loss: 2.0312 - val_accuracy: 0.4934
# Epoch 87/150
# 391/391 - 20s - loss: 1.4238 - accuracy: 0.5953 - val_loss: 2.0288 - val_accuracy: 0.4942
# Epoch 88/150
# 391/391 - 20s - loss: 1.4137 - accuracy: 0.5994 - val_loss: 2.0142 - val_accuracy: 0.4921
# Epoch 89/150
# 391/391 - 20s - loss: 1.4169 - accuracy: 0.5983 - val_loss: 2.0279 - val_accuracy: 0.4948
# Epoch 90/150
# 391/391 - 20s - loss: 1.4092 - accuracy: 0.5983 - val_loss: 2.0059 - val_accuracy: 0.4936
# Epoch 91/150
# 391/391 - 20s - loss: 1.4053 - accuracy: 0.6013 - val_loss: 2.0147 - val_accuracy: 0.4967
# Epoch 92/150
# 391/391 - 20s - loss: 1.4082 - accuracy: 0.6004 - val_loss: 2.0228 - val_accuracy: 0.4947
# Epoch 93/150
# 391/391 - 20s - loss: 1.3933 - accuracy: 0.6032 - val_loss: 2.0303 - val_accuracy: 0.4938
# Epoch 94/150
# 391/391 - 20s - loss: 1.4002 - accuracy: 0.6018 - val_loss: 2.0093 - val_accuracy: 0.4965
# Epoch 95/150
# 391/391 - 20s - loss: 1.3954 - accuracy: 0.6029 - val_loss: 2.0339 - val_accuracy: 0.4926
# Epoch 96/150
# 391/391 - 20s - loss: 1.3907 - accuracy: 0.6052 - val_loss: 2.0342 - val_accuracy: 0.4933
# Epoch 97/150
# 391/391 - 20s - loss: 1.3881 - accuracy: 0.6062 - val_loss: 1.9973 - val_accuracy: 0.4983
# Epoch 98/150
# 391/391 - 20s - loss: 1.3872 - accuracy: 0.6052 - val_loss: 2.0136 - val_accuracy: 0.4958
# Epoch 99/150
# 391/391 - 20s - loss: 1.3826 - accuracy: 0.6060 - val_loss: 2.0100 - val_accuracy: 0.4975
# Epoch 100/150
# 391/391 - 20s - loss: 1.3809 - accuracy: 0.6070 - val_loss: 2.0054 - val_accuracy: 0.4935
# Epoch 101/150
# 391/391 - 20s - loss: 1.3737 - accuracy: 0.6092 - val_loss: 2.0141 - val_accuracy: 0.4960
# Epoch 102/150
# 391/391 - 20s - loss: 1.3746 - accuracy: 0.6075 - val_loss: 2.0167 - val_accuracy: 0.4952
# Epoch 103/150
# 391/391 - 20s - loss: 1.3733 - accuracy: 0.6077 - val_loss: 2.0400 - val_accuracy: 0.4915
# Epoch 104/150
# 391/391 - 20s - loss: 1.3671 - accuracy: 0.6084 - val_loss: 2.0417 - val_accuracy: 0.4938
# Epoch 105/150
# 391/391 - 20s - loss: 1.3630 - accuracy: 0.6126 - val_loss: 2.0132 - val_accuracy: 0.4977
# Epoch 106/150
# 391/391 - 20s - loss: 1.3633 - accuracy: 0.6143 - val_loss: 2.0104 - val_accuracy: 0.4981
# Epoch 107/150
# 391/391 - 20s - loss: 1.3579 - accuracy: 0.6095 - val_loss: 2.0138 - val_accuracy: 0.4953
# Epoch 108/150
# 391/391 - 20s - loss: 1.3549 - accuracy: 0.6123 - val_loss: 2.0252 - val_accuracy: 0.4966
# Epoch 109/150
# 391/391 - 20s - loss: 1.3512 - accuracy: 0.6135 - val_loss: 2.0131 - val_accuracy: 0.5006
# Epoch 110/150
# 391/391 - 20s - loss: 1.3484 - accuracy: 0.6141 - val_loss: 2.0347 - val_accuracy: 0.4949
# Epoch 111/150
# 391/391 - 20s - loss: 1.3473 - accuracy: 0.6152 - val_loss: 2.0282 - val_accuracy: 0.4978
# Epoch 112/150
# 391/391 - 20s - loss: 1.3427 - accuracy: 0.6168 - val_loss: 2.0096 - val_accuracy: 0.4973
# Epoch 113/150
# 391/391 - 20s - loss: 1.3446 - accuracy: 0.6154 - val_loss: 2.0247 - val_accuracy: 0.4949
# Epoch 114/150
# 391/391 - 20s - loss: 1.3386 - accuracy: 0.6166 - val_loss: 2.0182 - val_accuracy: 0.4993
# Epoch 115/150
# 391/391 - 20s - loss: 1.3374 - accuracy: 0.6172 - val_loss: 2.0261 - val_accuracy: 0.5010
# Epoch 116/150
# 391/391 - 20s - loss: 1.3356 - accuracy: 0.6178 - val_loss: 2.0174 - val_accuracy: 0.4965
# Epoch 117/150
# 391/391 - 20s - loss: 1.3349 - accuracy: 0.6192 - val_loss: 2.0324 - val_accuracy: 0.4994
# Epoch 118/150
# 391/391 - 20s - loss: 1.3281 - accuracy: 0.6186 - val_loss: 2.0237 - val_accuracy: 0.4991
# Epoch 119/150
# 391/391 - 20s - loss: 1.3268 - accuracy: 0.6198 - val_loss: 2.0157 - val_accuracy: 0.5035
# Epoch 120/150
# 391/391 - 20s - loss: 1.3259 - accuracy: 0.6195 - val_loss: 2.0076 - val_accuracy: 0.5029
# Epoch 121/150
# 391/391 - 20s - loss: 1.3264 - accuracy: 0.6209 - val_loss: 2.0182 - val_accuracy: 0.5017
# Epoch 122/150
# 391/391 - 20s - loss: 1.3212 - accuracy: 0.6216 - val_loss: 2.0398 - val_accuracy: 0.4988
# Epoch 123/150
# 391/391 - 20s - loss: 1.3214 - accuracy: 0.6209 - val_loss: 2.0051 - val_accuracy: 0.5031
# Epoch 124/150
# 391/391 - 20s - loss: 1.3130 - accuracy: 0.6228 - val_loss: 2.0377 - val_accuracy: 0.4985
# Epoch 125/150
# 391/391 - 20s - loss: 1.3135 - accuracy: 0.6228 - val_loss: 2.0109 - val_accuracy: 0.5003
# Epoch 126/150
# 391/391 - 20s - loss: 1.3107 - accuracy: 0.6236 - val_loss: 2.0265 - val_accuracy: 0.4985
# Epoch 127/150
# 391/391 - 20s - loss: 1.3038 - accuracy: 0.6247 - val_loss: 2.0474 - val_accuracy: 0.4986
# Epoch 128/150
# 391/391 - 20s - loss: 1.3074 - accuracy: 0.6246 - val_loss: 2.0311 - val_accuracy: 0.5007
# Epoch 129/150
# 391/391 - 20s - loss: 1.3051 - accuracy: 0.6245 - val_loss: 2.0308 - val_accuracy: 0.5008
# Epoch 130/150
# 391/391 - 20s - loss: 1.2985 - accuracy: 0.6244 - val_loss: 2.0179 - val_accuracy: 0.5009
# Epoch 131/150
# 391/391 - 20s - loss: 1.3000 - accuracy: 0.6275 - val_loss: 2.0272 - val_accuracy: 0.5014
# Epoch 132/150
# 391/391 - 20s - loss: 1.2982 - accuracy: 0.6256 - val_loss: 2.0207 - val_accuracy: 0.4999
# Epoch 133/150
# 391/391 - 20s - loss: 1.2986 - accuracy: 0.6277 - val_loss: 2.0322 - val_accuracy: 0.5002
# Epoch 134/150
# 391/391 - 20s - loss: 1.2997 - accuracy: 0.6244 - val_loss: 2.0237 - val_accuracy: 0.5045
# Epoch 135/150
# 391/391 - 20s - loss: 1.2908 - accuracy: 0.6285 - val_loss: 2.0257 - val_accuracy: 0.5031
# Epoch 136/150
# 391/391 - 20s - loss: 1.2911 - accuracy: 0.6282 - val_loss: 2.0286 - val_accuracy: 0.5010
# Epoch 137/150
# 391/391 - 20s - loss: 1.2918 - accuracy: 0.6294 - val_loss: 2.0303 - val_accuracy: 0.5027
# Epoch 138/150
# 391/391 - 20s - loss: 1.2878 - accuracy: 0.6306 - val_loss: 2.0246 - val_accuracy: 0.5021
# Epoch 139/150
# 391/391 - 20s - loss: 1.2826 - accuracy: 0.6301 - val_loss: 2.0201 - val_accuracy: 0.5007
# Epoch 140/150
# 391/391 - 20s - loss: 1.2844 - accuracy: 0.6291 - val_loss: 2.0222 - val_accuracy: 0.5015
# Epoch 141/150
# 391/391 - 20s - loss: 1.2805 - accuracy: 0.6297 - val_loss: 2.0166 - val_accuracy: 0.5021
# Epoch 142/150
# 391/391 - 20s - loss: 1.2757 - accuracy: 0.6336 - val_loss: 2.0208 - val_accuracy: 0.5061
# Epoch 143/150
# 391/391 - 20s - loss: 1.2753 - accuracy: 0.6333 - val_loss: 2.0242 - val_accuracy: 0.5034
# Epoch 144/150
# 391/391 - 20s - loss: 1.2751 - accuracy: 0.6359 - val_loss: 2.0189 - val_accuracy: 0.5050
# Epoch 145/150
# 391/391 - 20s - loss: 1.2670 - accuracy: 0.6376 - val_loss: 2.0342 - val_accuracy: 0.5032
# Epoch 146/150
# 391/391 - 20s - loss: 1.2739 - accuracy: 0.6324 - val_loss: 2.0389 - val_accuracy: 0.5022
# Epoch 147/150
# 391/391 - 20s - loss: 1.2689 - accuracy: 0.6320 - val_loss: 2.0402 - val_accuracy: 0.5014
# Epoch 148/150
# 391/391 - 20s - loss: 1.2672 - accuracy: 0.6337 - val_loss: 2.0177 - val_accuracy: 0.5018
# Epoch 149/150
# 391/391 - 20s - loss: 1.2684 - accuracy: 0.6357 - val_loss: 2.0235 - val_accuracy: 0.5014
# Epoch 150/150
# 391/391 - 20s - loss: 1.2652 - accuracy: 0.6344 - val_loss: 2.0319 - val_accuracy: 0.5020

# %%
#plot Accuracy vs epochs
train_metrics = history.history['accuracy']
val_metrics = history.history['val_accuracy']
epochs = range(1, len(train_metrics) + 1)
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["training accuracy", 'test accuracy'])
plt.show()
#plot Validaiton loss vs epochs
train_metrics = history.history['loss']
val_metrics = history.history['val_loss']
plt.plot(epochs, train_metrics)
plt.plot(epochs, val_metrics)
plt.title('Training and Test Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["training loss", 'test loss'])
plt.show()

# %%
model = create_model()
# checkpoint_path = "../weights/ResNet18_ADAM_Dropouts"
checkpoint_path = "ResNet18_ADAM_Dropouts"
model.load_weights(checkpoint_path)
# loss,acc = model.evaluate(x_test,  y_test, verbose=2)
# print('Test Accuracy:', acc)
cm = confusion_matrix(y_test.argmax(axis=1), model.predict(x_test).argmax(-1))
print(cm)
precision = precision_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1), average='weighted')

accuracy= accuracy_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1))
recall= recall_score(y_test.argmax(axis=1), model.predict(x_test).argmax(-1), average='weighted')

print('precision:', precision)
print('accuracy:', accuracy)
print('recall:', recall)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-5.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-5.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-7.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-8.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-9.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-9.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-10.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-10.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-11.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-11.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-12.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-12.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-13.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-13.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-14.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-14.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-15.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-15.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-16.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-16.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-17.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-17.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-18.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-18.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-19.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-19.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-20.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-20.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-21.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-21.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-5.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-5.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-7.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-8.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-8.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-9.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-9.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-10.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-10.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-11.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-11.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-12.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-12.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-13.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-13.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-14.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-14.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-15.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-15.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-16.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-16.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-17.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-17.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-18.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-18.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-19.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-19.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-20.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-20.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-21.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-21.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# [[81  2  0 ...  0  0  0]
#  [ 0 58  0 ...  0  0  1]
#  [ 0  0 38 ...  0  3  0]
#  ...
#  [ 0  0  0 ... 45  0  0]
#  [ 0  1  7 ...  0 28  3]
#  [ 0  1  1 ...  0  0 57]]
# precision: 0.5054630040194593
# accuracy: 0.5061
# recall: 0.5061
